# %%
import os
from dotenv import load_dotenv

# Load variables from .env file
load_dotenv()

# Access the variables
APIFY_TOKEN = os.getenv("APIFY_TOKEN")

# %% [markdown]
# ## Live running the Apify, could simiply request the output instead

# %%
from apify_client import ApifyClient

# Initialize the ApifyClient with your API token
client = ApifyClient(APIFY_TOKEN)

# Prepare the Actor input
run_input = {
    "queries": "Teacher\nhttps://www.google.com/search?q=doctor&ibp=htl;jobs",
    "maxPagesPerQuery": 1,
    "csvFriendlyOutput": False,
    "languageCode": "",
    "maxConcurrency": 10,
    "saveHtml": False,
    "saveHtmlToKeyValueStore": False,
    "includeUnfilteredResults": False,
}

# Run the Actor and wait for it to finish
run = client.actor("SpK8RxKhIgV6BWOz9").call(run_input=run_input)

# Fetch and print Actor results from the run's dataset (if there are any)
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    print(item)

# %%
def traverse_json(obj, indent=''):
    if isinstance(obj, dict):
        for key, value in obj.items():
            print(f"{indent}{key}:")
            traverse_json(value, indent + '  ')
    elif isinstance(obj, list):
        for item in obj:
            traverse_json(item, indent + '  ')
    else:
        print(f"{indent}{obj}")

# Replace 'json_object' with the actual JSON object you want to traverse

traverse_json(item)
# Out:
# searchQuery:
#   term:
#     doctor
#   page:
#     1
#   type:
#     SEARCH
#   domain:
#     google.com
#   countryCode:
#     US
#   languageCode:
#     None
#   locationUule:
#     None
#   resultsPerPage:
#     10
# url:
#   https://www.google.com/search?q=doctor&ibp=htl;jobs
# hasNextPage:
#   True
# googleJobs:
#     title:
#       Veterinarian Doctor
#     companyName:
#       Lap of Love
#     location:
#         Vancouver, WA
#     via:
#       via BeBee
#     description:
#       Are you ready for a change of pace from in-clinic practice? Looking to reconnect with pet families and provide the kind of service you'd always envisioned by having generous appointment times and minimal administrative work? At Lap of Love, our mission is to provide support to pets and their families during one of life's most challenging moments by helping pets pass peacefully in the comfort of... their own home.
# Established and owned by veterinarians, we recognize that pets are more than just animals — they're beloved family members. That's why we prioritize deep and meaningful connections with pet families, colleagues, and the community. Embrace the freedom of a mobile practice, without being tied to a clinic
# • Benefit from comprehensive training and ongoing mentorship
# • Enjoy schedule flexibility, with 2-5 day-per-week work options with most appointments occurring between 9 am - 5 pm
# • Collaborate with an active community of 300+ doctors who support one another and have fun, too
# Provide in-home euthanasia and hospice care for geriatric and terminally ill pets
# • Build relationships with local veterinary clinics, serving as an extension of their excellent care
# Doctor of Veterinary Medicine (DVM/VMD/BVMS)
# • Possess a valid driver's license and a well-maintained SUV/hatchback/minivan
# • Range of health insurance plans, including vision and dental, with options for both individual and family coverage
# • Retirement Plan (Traditional 401k with 3% match and Roth 401k)
# • Professional Training and Development
# • Wellness Resources (Mental, Physical, and Financial)
# • At Lap of Love, our mobile veterinarians derive deep fulfillment and satisfaction from making a difference in the lives of countless pets and the people who love them by helping pets pass with dignity in the comfort of their own home
#     jobHighlights:
#         title:
#           Qualifications
#         items:
#             Possess a valid driver's license and a well-maintained SUV/hatchback/minivan
#         title:
#           Responsibilities
#         items:
#             Provide in-home euthanasia and hospice care for geriatric and terminally ill pets
#             Build relationships with local veterinary clinics, serving as an extension of their excellent care
#         title:
#           Benefits
#         items:
#             Benefit from comprehensive training and ongoing mentorship
#             Enjoy schedule flexibility, with 2-5 day-per-week work options with most appointments occurring between 9 am - 5 pm
#             Retirement Plan (Traditional 401k with 3% match and Roth 401k)
#     relatedLinks:
#         link:
#           http://www.lapoflove.com/
#         text:
#           lapoflove.com
#         link:
#           https://www.google.com/search?sca_esv=592980130&q=Lap+of+Love&sa=X&ved=0ahUKEwinq6TH_6GDAxUBJzQIHcAcBQ8QmJACCNAJ
#         text:
#           See web results for Lap of Love
#     thumbnail:
#       https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ_OnXN-AvMErRRwRr-6wvVHgMnjRBtRfkuJgeW8UU&s
#     extras:
#         1 day ago
#         Full-time
#         Health insurance
#         Dental insurance
#     metadata:
#       postedAt:
#         1 day ago
#       scheduleType:
#         Full-time
#     applyLink:
#       title:
#         .nFg2eb{font-weight:500}.Bi6Ddc{font-weight:500}Apply on BeBee
#       link:
#         https://us.bebee.com/job/20231220-f1a3ccdb5b8784133c2f6322dbfa33e9?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic
#     title:
#       Primary Care Medical Doctor Full Time
#     companyName:
#       UnitedHealth Group
#     location:
#         Camas, WA
#     via:
#       via Jobs Trabajo.org
#     description:
#       As a part of Optum, the largest network of medical groups in the country, Greenfield Health Clinic is seeking a Full Time Family/Internal Medicine Physician to join our team in Portland, OR . At Optum, we are transforming healthcare nationally while providing physician-led care locally. Work with the largest care delivery organization in the world and start doing your life’s best work.
# GreenField... Health is a patient-centered, primary care medical home that provides proactive and comprehensive evidence-based care. We forge deep relationships with outpatients through the delivery of impeccable service and reliably innovative clinical care. Partnerships with trusted specialists help us meet all the care needs of our patients. Our clinic is conveniently located off Highway 26 and 217, adjacent to Providence St. Vincent Medical Center and the Sunset Transit Station.
# This is a traditional outpatient primary care medicine practice supporting patients from Portland and its surrounding communities: We offer a competitive compensation and benefits package with productivity and quality incentives. Leadership pathways available at the local/clinical, regional or national level.
# Outpatient: Primary Care including office consults, annual visits, follow up appointments and in office procedures
# ~ Ancillary Primary Care team includes Social Work, Behavioral Health, Physical Therapy, and Pharmacy
# ~ general in office procedures
# ~ Medical Assistant to support Physician; Welcome New Family/Internal Medicine Grads
#
# You’ll be rewarded and recognized for your performance in an environment that will challenge you and give you clear direction on what it takes to succeed in your role as well as provide development for other roles you may be interested in.
#
# Graduate of four-year U.Medical School or equivalent. Residency completed in Family Medicine or Internal Medicine
# Leadership Pathways and Partnership
# CME Reimbursement and Related Time Off
# To help people live healthier lives and help make the health system work better for everyone.
# Compassion: Walk in the shoes of people we serve and those with whom we work.
# Innovation: Invent the future, learn from the past.
# Performance: Demonstrate excellence in everything we do.
# From our flexible delivery models to evidence-based interventions, we're approaching care in a unique way - unlike anyone else in the marketplace. Care delivery represents a significant investment, growth and performance opportunity for Optum and you.
# Our initial on-line application process will take you less than two minutes to complete
# At UnitedHealth Group, our mission is to help people live healthier lives and make the health system work better for everyone. Today, however, there are still far too many barriers to good health which are disproportionately experienced by people of color, historically marginalized groups and those with lower incomes. We are committed to mitigating our impact on the environment and enabling and delivering equitable care that addresses health disparities and improves health outcomes - an enterprise priority reflected in our mission.
# Diversity creates a healthier atmosphere: UnitedHealth Group is an Equal Employment Opportunity/Affirmative Action employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, age, national origin, protected veteran status, disability status, sexual orientation, gender identity or expression, marital status, genetic information, or any other characteristic protected by law.
# UnitedHealth Group is a drug - free workplace
#     jobHighlights:
#         title:
#           Qualifications
#         items:
#             Graduate of four-year U.Medical School or equivalent
#             Residency completed in Family Medicine or Internal Medicine
#         title:
#           Responsibilities
#         items:
#             Outpatient: Primary Care including office consults, annual visits, follow up appointments and in office procedures
#             ~ Ancillary Primary Care team includes Social Work, Behavioral Health, Physical Therapy, and Pharmacy
#             You’ll be rewarded and recognized for your performance in an environment that will challenge you and give you clear direction on what it takes to succeed in your role as well as provide development for other roles you may be interested in
#         title:
#           Benefits
#         items:
#             This is a traditional outpatient primary care medicine practice supporting patients from Portland and its surrounding communities: We offer a competitive compensation and benefits package with productivity and quality incentives
#             CME Reimbursement and Related Time Off
#     relatedLinks:
#         link:
#           https://www.unitedhealthgroup.com/
#         text:
#           unitedhealthgroup.com
#         link:
#           https://www.google.com/search?sca_esv=592980130&q=UnitedHealth+Group&sa=X&ved=0ahUKEwinq6TH_6GDAxUBJzQIHcAcBQ8QmJACCJUK
#         text:
#           See web results for UnitedHealth Group
#     thumbnail:
#       https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRy7BDVLI1v0TTiEd_1-A9erQIeLXnbzmstT3FzCrk&s
#     extras:
#         7 hours ago
#         Full-time
#         Health insurance
#     metadata:
#       postedAt:
#         7 hours ago
#       scheduleType:
#         Full-time
#     applyLink:
#       title:
#         Apply on Jobs Trabajo.org
#       link:
#         https://us.trabajo.org/job-1275-20231221-791df4660e37ec1c7e8a9c4fc8906ac6?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic
#     title:
#       Doctor of Chiropractic
#     companyName:
#       Medulla
#     location:
#         Vancouver, WA
#     via:
#       via ZipRecruiter
#     description:
#       Doctor of Chiropractic
#
# We are hiring Doctors of Chiropractic to join our team in Washington...
#
# $70K base to start
#
# Opportunity - You will be able to pursue your passion of caring for patients in a comprehensive chiropractic family practice to custom tailor our patient's unique needs. Without the added stress of every entrepreneur's nightmare - having to be everything for everyone.
#
# Competitive Salary and Compensation - We offer a highly competitive salary and compensation package, including the ability to share in the profitability of your clinic- our Clinic Director average salary is well over $200K!
#
# Business Support - You are hired to be the doctor and not a marketer, accountant, IT professional nor a facilities manager. We provide assistance, proven results and support in these critical areas of clinical success via:
# • Marketing - We average over 45 new patients a month per office
# • Billing and Collections - We average over $1.1 million in collections per clinic annually
# • DC coaching/Practice Management - Our coaching staff has literally over 30 years of clinical and business experience with a successful track record of proven extraordinary results.
# • CA/CT Recruiting & Training - We provide monthly recruiting and training of your clinic support staff.
# • Professional Development - A rising tide raises all ships. You will be amongst some of the most successful DC's and businesspersons in the profession.
#
# Job Requirements:
# • Degree from an accredited university/college of Chiropractic
# • Chiropractic license in the state of Washington
# • Encourages accountability among team members and patients.
# • Promotes a balanced, healthy lifestyle centered on chiropractic.
# • Possesses strong ability to create, plan and achieve goals.
# • Possesses ability to remain calm and professional during difficult situations (including employee write ups, patient upset etc.).
# • Uses clear and professional verbal and written communication.
# • Possesses ability to manage multiple projects and meet deadlines
#
# Disclaimer
#
# All team members agree to consistently support compliance and TVG-Medulla, LLC policies and Standards of Excellence with regard to maintaining the privacy and confidentiality of information, protecting the assets of the organization, acting with ethics and integrity, reporting non-compliance, adhering to applicable federal, state, and local laws and regulations, accreditation, and licenser requirements (if applicable), and Medulla procedures and protocols. Must perform other related duties and assist with project completion as needed. Team member may be required to provide necessary information to complete a DMV (or equivalent agency) background check
#     jobHighlights:
#         title:
#           Qualifications
#         items:
#             Degree from an accredited university/college of Chiropractic
#             Chiropractic license in the state of Washington
#             Possesses strong ability to create, plan and achieve goals
#             Possesses ability to remain calm and professional during difficult situations (including employee write ups, patient upset etc.)
#             Uses clear and professional verbal and written communication
#             Possesses ability to manage multiple projects and meet deadlines
#             Team member may be required to provide necessary information to complete a DMV (or equivalent agency) background check
#         title:
#           Responsibilities
#         items:
#             Encourages accountability among team members and patients
#         title:
#           Benefits
#         items:
#             $70K base to start
#             Competitive Salary and Compensation - We offer a highly competitive salary and compensation package, including the ability to share in the profitability of your clinic- our Clinic Director average salary is well over $200K!
#             Billing and Collections - We average over $1.1 million in collections per clinic annually
#     relatedLinks:
#         link:
#           https://www.google.com/search?sca_esv=592980130&q=Medulla&sa=X&ved=0ahUKEwinq6TH_6GDAxUBJzQIHcAcBQ8QmJACCOAK
#         text:
#           See web results for Medulla
#     extras:
#         22 days ago
#         Full-time
#         Health insurance
#     metadata:
#       postedAt:
#         22 days ago
#       scheduleType:
#         Full-time
#     applyLink:
#       title:
#         Apply on ZipRecruiter
#       link:
#         https://www.ziprecruiter.com/c/Medulla/Job/Doctor-of-Chiropractic/-in-Vancouver,WA?jid=14b5fb5b97904a30&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic
#     title:
#       Permanent | Physician Hematology Oncology
#     companyName:
#       CompHealth
#     location:
#         Vancouver, WA
#     via:
#       via LinkedIn
#     description:
#       Vancouver is a city on the north bank of the Columbia River directly across from Portland, Oregon. The Pacific Coast is less than 90 miles to the west. The Cascade Mountain Range rises on the east. Mount St. Helens National Volcanic Monument and Mt. Hood are less than two hours away. The spectacular Columbia River Gorge National Scenic Area lies 30 minutes to the east. Vancouver combines the... excitement of a major metropolitan area with small-town charm and abundant recreational opportunities.
#
# Contact your personal consultant to tell them what you are looking for in a new position. CompHealth can make finding great opportunities simple, less stressful, and personalized to fit your needs. We have phenomenal relationships with facilities around the country, and a team dedicated to helping you with every step of the hiring process.
#
# Contact Madison Tourville madison.tourville@comphealth.com (954) 616-2933.
# • Live in Washington state in a wonderful suburb of Portland, Oregon; no state income tax
# • 4-day clinic work week; 1 admin day can be done at home
# • Beautiful location close to an international airport; great schools and new homes
# • Physician-focused group
# • Active clinical trials and tumor boards
# • Strong earning potential with the possibility of coming off base salary at any time
# • Sign-on bonus and relocation assistance
# • J-1 and H-1B candidates are welcome to apply
# • Our services are free for you
# • We help negotiate your salary and contract
# • We coordinate interviews and help with licenses
# • Specialized recruiters match your career preferences
# • Experienced support teams take care of every detail
#
# Salary from $450000.00 to $800000.00 annually
#
# Ranges shown should be used as an estimate and are affected by many factors including the critical need of the position, your overall experience and qualifications, and other considerations. Please reach out to your consultant for more information
#     jobHighlights:
#         title:
#           Benefits
#         items:
#             4-day clinic work week; 1 admin day can be done at home
#             Strong earning potential with the possibility of coming off base salary at any time
#             Sign-on bonus and relocation assistance
#             We help negotiate your salary and contract
#             Salary from $450000.00 to $800000.00 annually
#     relatedLinks:
#         link:
#           https://www.google.com/search?sca_esv=592980130&q=CompHealth&sa=X&ved=0ahUKEwinq6TH_6GDAxUBJzQIHcAcBQ8QmJACCKIL
#         text:
#           See web results for CompHealth
#     thumbnail:
#       https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRhXLAiPuBTWBxbJdaoHjgXENxSgwkMIFfaf_5WQrU&s
#     extras:
#         3 days ago
#         Contractor
#     metadata:
#       postedAt:
#         3 days ago
#       scheduleType:
#         Contractor
#     applyLink:
#       title:
#         Apply on LinkedIn
#       link:
#         https://www.linkedin.com/jobs/view/permanent-physician-hematology-oncology-at-comphealth-3787624284?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic
#     title:
#       Feline Exclusive Practice Looking for a 5th Doctor for our Hospital
#     companyName:
#       Feline Medical Clinic
#     location:
#         Vancouver, WA
#     via:
#       via CUCVM Job Board
#     description:
#       The Feline Medical Clinic is adding a 5 th Doctor to our hospital team in Vancouver, Washington. We are certified as a Silver-level Cat Friendly Practice. We have a dedicated client base which has supported us for decades (we were founded in 1977 and have been AAHA-certified since 1979). Clients typically have finances to pursue diagnostic and surgical treatments. Client education about cats is... still a large part of our daily practice. Our staff is a team which strives to improve and upgrade our care. Most team members have been with us for many years. Three licensed techs and multiple highly-skilled and trained assistants are our basis for excellence. We support the entire team to help us all do our jobs well and with long-term career goals in mind. The doctors all share cases and treat by the same protocols so mentorship is part of our daily practice. This also means casework continues uninterrupted on scheduled days off for each doctor. We are not on call, nor do we have late hours. We support a work-life balance, and the calendar is set months in advance so it is possible to schedule important vacations and events outside of work and be able to count on this time. We have a vacation policy which is granted during the first year of practice after an initial probation period. We are close to hiking, biking, and beach recreation. We have a strong interest in the ABVP and are active in our support for becoming board-certified in feline practice. We encourage attendance at, and budget for, at least one major meeting for each doctor every year. We have digital dental radiography (and include full mouth dental radiographs with every dental) and standard digital radiology machines as well as high-quality patient monitors as recommended by AAHA standards. We also have a butterfly ultrasound machine we are learning to incorporate into our diagnostic tree. We have brand new surgical and dental LED lighting and an LED swivel dental drill for the dental procedures we routinely perform.
#
# If you are interested in our practice and becoming our new doctor (and we welcome new graduates for this position), please send a letter of interest and resume to the email address below. We try to address inquiries promptly, but if the doctor who is overseeing the hiring is on vacation or a weekend off (all the doctors get at least one long weekend per month) it may be a few days before a reply is made. We will do our best to make ALL applicants feel welcome.
#
# Carrie Burhenn DVM dABVP(feline practice) practice website: www.felinemedicalclinic.com
#
# felineclinic@aol.com
#
# Full time Associate
#     jobHighlights:
#         title:
#           Benefits
#         items:
#             We support a work-life balance, and the calendar is set months in advance so it is possible to schedule important vacations and events outside of work and be able to count on this time
#             We have a vacation policy which is granted during the first year of practice after an initial probation period
#     relatedLinks:
#         link:
#           https://www.google.com/search?sca_esv=592980130&q=Feline+Medical+Clinic&sa=X&ved=0ahUKEwinq6TH_6GDAxUBJzQIHcAcBQ8QmJACCOAL
#         text:
#           See web results for Feline Medical Clinic
#     extras:
#         7 days ago
#         Full-time
#         Paid time off
#     metadata:
#       postedAt:
#         7 days ago
#       scheduleType:
#         Full-time
#     applyLink:
#       title:
#         Apply on CUCVM Job Board
#       link:
#         https://cvmjobs.vet.cornell.edu/jobs/19522677/feline-exclusive-practice-looking-for-a-5th-doctor-for-our-hospital?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic
#     title:
#       Family medicine physician
#     companyName:
#       AMN Healthcare
#     location:
#         Battle Ground, WA
#     via:
#       via Talent.com
#     description:
#       Job Details
#
# This facility is seeking a Family Medicine Physician or Doctor of Osteopathy for locum tenens support as they look to fill a current need...
#
# Details and requirements for this opportunity.
# • Schedule : Monday-Friday, 8am-5pm
# • Types of Cases : Standard Primary Care
# • Credentialing Timeframe : 3 weeks
# • Active Washington state license and Drug Enforcement Administration (DEA) certification required
# • Primary Care experience in Community Medicine preferred
#
# Benefits
#
# AMN Healthcare typically arranges medical or dental malpractice insurance for the contractor providers we match to client opportunities.
#
# In addition, our locum tenens can receive highly competitive pay and a dedicated team that handles all travel, lodging, rentals and transportation needs.
#
# Additionally, our Physician Mobility initiative decreases the amount of time you must wait to work at a facility where you are presented or have worked from 24 months to 6 months.
#
# About Company
#
# Staff Care, an AMN Healthcare company, is the nation's leader in locum tenens staffing. We provide flexible, temporary employment options for physicians, clinicians, and other allied health professionals in all specialties with a variety of healthcare organizations, typically with interim contracts lasting from one week to one year.
#
# AMN Healthcare is an EEO / AA / Disability / Protected Veteran Employer. We encourage minority and female applicants to apply.
#
# Last updated : 2023-12-11
#     jobHighlights:
#         title:
#           Qualifications
#         items:
#             Credentialing Timeframe : 3 weeks
#             Active Washington state license and Drug Enforcement Administration (DEA) certification required
#         title:
#           Responsibilities
#         items:
#             Schedule : Monday-Friday, 8am-5pm
#     relatedLinks:
#         link:
#           http://www.amnhealthcare.com/
#         text:
#           amnhealthcare.com
#         link:
#           https://www.google.com/search?sca_esv=592980130&q=AMN+Healthcare&sa=X&ved=0ahUKEwinq6TH_6GDAxUBJzQIHcAcBQ8QmJACCJ8M
#         text:
#           See web results for AMN Healthcare
#     extras:
#         11 days ago
#         Full-time and Temp work
#     metadata:
#       postedAt:
#         11 days ago
#       scheduleType:
#         Full-time and Temp work
#     applyLink:
#       title:
#         Apply on Talent.com
#       link:
#         https://www.talent.com/view?id=0f53e7494bda&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic
#     title:
#       Family Medicine Physician or Doctor of Osteopathy
#     companyName:
#       AMN Corporate
#     location:
#         Battle Ground, WA
#     via:
#       via AMN Healthcare
#     description:
#       This facility is seeking a Family Medicine Physician or Doctor of Osteopathy for locum tenens support as they look to fill a current need.
#
# Details and requirements for this opportunity...
# • Schedule: Monday-Friday, 8am-5pm
# • Job Setting: Standard outpatient
# • Types of Cases: Standard Primary Care
# • Credentialing Timeframe: 3 weeks
# • Active Washington state license and Drug Enforcement Administration (DEA) certification required
# • Primary Care experience in Community Medicine preferred
#     jobHighlights:
#         title:
#           Qualifications
#         items:
#             Credentialing Timeframe: 3 weeks
#             Active Washington state license and Drug Enforcement Administration (DEA) certification required
#         title:
#           Responsibilities
#         items:
#             Schedule: Monday-Friday, 8am-5pm
#     relatedLinks:
#         link:
#           https://www.google.com/search?sca_esv=592980130&q=AMN+Corporate&sa=X&ved=0ahUKEwinq6TH_6GDAxUBJzQIHcAcBQ8QmJACCOIM
#         text:
#           See web results for AMN Corporate
#     extras:
#         129.01–139.65 an hour
#         Temp work
#     metadata:
#       scheduleType:
#         Temp work
#       salary:
#         129.01–139.65 an hour
#     applyLink:
#       title:
#         Apply directly on AMN Healthcare
#       link:
#         https://www.amnhealthcare.com/job-details/2956137/battle-ground-wa-family-medicine-/?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic
#     title:
#       Medical Doctor
#     companyName:
#       National Medical Association
#     location:
#         Vancouver, WA
#     via:
#       via BeBee
#     description:
#       Details Posted: 14-Oct-23
#
# Location:
# Vancouver, Washington, Washington
#
# Salary:
# Open
#
# Categories:
# Physicians/Surgeons Internal Number: 744407700
#
# Stand ready with VA to help in an emergency A disaster can strike at any time - an earthquake, tornado, hurricane, or global pandemic can leave our Veterans, families, and communities in desperate need of help.
# That's why the U.S. Department of Veterans Affairs (VA) is creating Clinical Deployment Teams (CDTs) to stand ready to assist.
#
# We're looking for clinical personnel to serve on these teams and help transform how we provide health care services in times of great need.
#
# Applicants pending the completion of educational or certification/licensure requirements may be referred and tentatively selected but may not be hired until all requirements are met.
#
# Basic Requirements:
#
# United States Citizenship:
#
# Non-citizens may only be appointed when it is not possible to recruit qualified citizens in accordance with VA Policy.
# English Language... Proficiency. In accordance with 38 U.S.C.
#
# 7402(d), no person shall serve in direct patient care positions unless they are proficient in basic written and spoken English.
#
# Degree of doctor of medicine or an equivalent degree resulting from a course of education in medicine or osteopathic medicine.
#
# The degree must have been obtained from one of the schools approved by the Department of Veterans Affairs for the year in which the course of study was completed.
#
# Current, full and unrestricted license to practice medicine or surgery in a State, Territory, or Commonwealth of the United States, or in the District of Columbia.
#
# Residency Training:
# Physicians must have completed residency training, approved by the Secretary of Veterans Affairs in an accredited core specialty training program leading to eligibility for board certification
#
# (NOTE:
#
# VA physicians involved in academic training programs may be required to be board certified for faculty status.)
#
# Approved residencies are:
# (1)
#
# Those approved by the Accreditation Council for Graduate Medical Education (ACGME), b) OR [(2) Those approved by the American Osteopathic Association (AOA),OR (3) Other residencies (non-US residency training programs followed by a minimum of five years of verified practice in the United States), which the local Medical Staff Executive Committee deems to have provided the applicant with appropriate professional training and believes has exposed the physician to an appropriate range of patient care experiences.
#
# Residents currently enrolled in ACGME/AOA accredited residency training programs and who would otherwise meet the basic requirements for appointment are eligible to be appointed as "Physician Resident Providers" (PRPs).
#
# PRPs must be fully licensed physicians (i.e., not a training license) and may only be appointed on an intermittent or fee-basis.
#
# PRPs are not considered independent practitioners and will not be privileged; rather, they are to have a "scope of practice" that allows them to perform certain restricted duties under supervision.
# Additionally, surgery residents in gap years may also be appointed as PRPs. Preferred Experience and Certifications All Specialties Experience in disaster medicine and/or completed advanced training (i.e. fellowship) in disaster or wilderness medicine. This may include experience in medical deployments. Additionally, training and/or experience in critical care medicine is favored. Advanced Trauma Life Support (ATLS) Certifications from American Heart Association (AHA) or Military Training Network (MTN) are highly preferred:
# Basic Life Support (BLS) and/or Advanced Cardiac Life Support (ACLS).
#
# (AHA certification preferred.) BLS/ACLS certification is recommended, but not required, for candidates who are board certified in Emergency Medicine (VHA Directive 1177, Cardiopulmonary Resuscitation, January 4, 2021).
#
# The selected employee will be required to receive these certifications prior to assuming clinical responsibilities and ensure current certifications after employment is maintained.
# Primary Care 3 or more years of experience in a Primary Care Setting. Prior experience in the hospital, emergency or trauma setting. Board Certified/Board Eligible in Internal Medicine or Family Practice.
#
# Reference:
# VA Regulations, specifically VA Handbook 5005, Part II, Appendix G2 Physician Qualification Standard. This can be found in the local Human Resources Office.
#
# Physical Requirements:
#
# Eligible applicants must be physically and mentally able to perform efficiently the essential functions of the position, with or without reasonable accommodation, without hazard to themselves or others.
# Depending on the essential duties of a specific position, usable vision, color vision, hearing or speech may be required.
#
# however, in most cases, a specific physical condition or impairment of a specific function may be compensated for by the satisfactory use of a prosthesis or mechanical aid.
#
# Moderate carrying and lifting (15-44 pounds); Straight pulling and pushing (0.5 hours); Reaching above shoulder; Use of fingers; Walking (4 hours); Standing (4 hours); Kneeling (0.5 hours); Depth perception; Ability to distinguish basic colors; Hearing (aid may be permitted).; Mental and emotional stability.
#
# Environmental Factors:
# Working closely with others and working alone.
#
# ["Working in Primary Care, Medical-Surgical, Emergency Room (ER), and Intensive Care Unit (ICU), Clinical Deployment Team (CDT) staff will be allocated among 18 networks for a total of 20 full-time employees per network, including 11 Registered Nurses (RNs), 2 Licensed Practical Nurses (LPNs) or Licensed Vocational Nurses (LVNs), 5 providers (including Medical Doctors, Doctors of Osteopathic Medicine, and Advanced Nurse Practitioners) and 2 Social Workers.
# When they are not deployed, CDT staff will work at an assigned VA facility.
#
# Members of the team must:
#
# Be available to deploy with 72 hours' notice within 2 windows of time per calendar year, for up to a month at a time Work in a high-stress environment, possibly in austere conditions or an emergency setting Treat or provide direct patient care within the requirements of practice/privileges/licensure Participate in CDT training activities and demonstrate readiness to apply professional skills to a range of emergency situations Ensure qualifications and required certifications are maintained, including Basic Life Support (BLS), Advanced Cardiac Life Support (ACLS), or Advanced Trauma Life Support (ATLS) certification Maintain CDT physical readiness requirements, vaccinations, and safety precautions related to infection control Physicians on the CDT may work in one of the following areas: Primary Care - Serve on a Patient Aligned Care Team (PACT) and will be responsible for providing medical care in an outpatient setting following PACT principles.
# May provide medical care using Telehealth for remote patients or travel to other outpatient clinics to cover provider shortage. The patient population ranges from adult to geriatrics. Diagnose, treat, and manage a panel of patients. Provide comprehensive patient-centered primary medical care.
#
# VA offers a comprehensive total rewards package:
#
# VHA
#
# Physician Total Rewards Work Schedule:
# Monday - Friday 7:00 am - 4:30 pm. May vary depending on deployment and/or assigned facility needs.
#
# May vary depending on deployment and/or assigned facility needs Compressed/Flexible:
#
# Available Telework:
#
# Available Travel:
# Up to 50% may be required
#
# Virtual:
# This is not a virtual position.
#
# Relocation/Recruitment Incentives (Sign-on Bonus): NOT Authorized EDRP Authorized: This position is eligible for the Education Debt Reduction Program (EDRP), a student loan payment reimbursement program.
#
# You must meet specific individual eligibility requirements in accordance with
# VHApolicy and submit your EDRP application within four months of appointment.
#
# Approval, award amount (up to $200,000) and eligibility period (one to five years) are determined by the
# VHAEducation Loan Repayment Services program office after complete review of the EDRP application.
# Contact and , the EDRP Coordinator for questions/assistance. Learn more.
#
# Permanent Change of Station (PCS):
# NOT Authorized PCS Appraised Value Offer (AVO): NOT
#
# Authorized Pay:
# Competitive salary, annual performance bonus, regular salary increases
# Paid Time Off: 50-55 days of annual paid time offer per year (26 days of annual leave, 13 days of sick leave, 11 paid Federal holidays per year and possible 5 day paid absence for CME)
#
# Retirement:
# Traditional federal pension (5 years vesting) and federal 401K with up to 5% in contributions by VA Insurance: Federal health/vision/dental/term life/long-term care (many federal insurance programs can be carried into retirement)
#
# Licensure: 1 full and unrestricted license from any US State or territory
#
# CME:
# Possible $1,000 per year reimbursement (must be full-time with board certification)
#
# Malpractice:
#
# Free liability protection with tail coverage provided Contract: No Physician Employment Contract"] Create a Job Alert for Similar Jobs About Veterans Affairs, Veterans Health Administration The Veterans Health Administration is America's largest integrated health care system, providing care at 1,298 health care facilities, including 171 medical centers and 1,113 outpatient sites of care of varying complexity (VHA outpatient clinics), serving 9 million enrolled Veterans each year.
# Connections working at Veterans Affairs, Veterans Health Administration More Jobs from This Employer #J-18808-Ljbffr
#     jobHighlights:
#         items:
#             Details Posted: 14-Oct-23
#
# Location:
# Vancouver, Washington, Washington
#
# Salary:
# Open
#
# Categories:
# Physicians/Surgeons Internal Number: 744407700
#
# Stand ready with VA to help in an emergency A disaster can strike at any time - an earthquake, tornado, hurricane, or global pandemic can leave our Veterans, families, and communities in desperate need of help.
# That's why the U.S. Department of Veterans Affairs (VA) is creating Clinical Deployment Teams (CDTs) to stand ready to assist.
#
# We're looking for clinical personnel to serve on these teams and help transform how we provide health care services in times of great need.
#
# Applicants pending the completion of educational or certification/licensure requirements may be referred and tentatively selected but may not be hired until all requirements are met.
#
# Basic Requirements:
#
# United States Citizenship:
#
# Non-citizens may only be appointed when it is not possible to recruit qualified citizens in accordance with VA Policy.
# English Language... Proficiency. In accordance with 38 U.S.C.
#
# 7402(d), no person shall serve in direct patient care positions unless they are proficient in basic written and spoken English.
#
# Degree of doctor of medicine or an equivalent degree resulting from a course of education in medicine or osteopathic medicine.
#
# The degree must have been obtained from one of the schools approved by the Department of Veterans Affairs for the year in which the course of study was completed.
#
# Current, full and unrestricted license to practice medicine or surgery in a State, Territory, or Commonwealth of the United States, or in the District of Columbia.
#
# Residency Training:
# Physicians must have completed residency training, approved by the Secretary of Veterans Affairs in an accredited core specialty training program leading to eligibility for board certification
#
# (NOTE:
#
# VA physicians involved in academic training programs may be required to be board certified for faculty status.)
#
# Approved residencies are:
# (1)
#
# Those approved by the Accreditation Council for Graduate Medical Education (ACGME), b) OR [(2) Those approved by the American Osteopathic Association (AOA),OR (3) Other residencies (non-US residency training programs followed by a minimum of five years of verified practice in the United States), which the local Medical Staff Executive Committee deems to have provided the applicant with appropriate professional training and believes has exposed the physician to an appropriate range of patient care experiences.
#
# Residents currently enrolled in ACGME/AOA accredited residency training programs and who would otherwise meet the basic requirements for appointment are eligible to be appointed as "Physician Resident Providers" (PRPs).
#
# PRPs must be fully licensed physicians (i.e., not a training license) and may only be appointed on an intermittent or fee-basis.
#
# PRPs are not considered independent practitioners and will not be privileged; rather, they are to have a "scope of practice" that allows them to perform certain restricted duties under supervision.
# Additionally, surgery residents in gap years may also be appointed as PRPs. Preferred Experience and Certifications All Specialties Experience in disaster medicine and/or completed advanced training (i.e. fellowship) in disaster or wilderness medicine. This may include experience in medical deployments. Additionally, training and/or experience in critical care medicine is favored. Advanced Trauma Life Support (ATLS) Certifications from American Heart Association (AHA) or Military Training Network (MTN) are highly preferred:
# Basic Life Support (BLS) and/or Advanced Cardiac Life Support (ACLS).
#
# (AHA certification preferred.) BLS/ACLS certification is recommended, but not required, for candidates who are board certified in Emergency Medicine (VHA Directive 1177, Cardiopulmonary Resuscitation, January 4, 2021).
#
# The selected employee will be required to receive these certifications prior to assuming clinical responsibilities and ensure current certifications after employment is maintained.
# Primary Care 3 or more years of experience in a Primary Care Setting. Prior experience in the hospital, emergency or trauma setting. Board Certified/Board Eligible in Internal Medicine or Family Practice.
#
# Reference:
# VA Regulations, specifically VA Handbook 5005, Part II, Appendix G2 Physician Qualification Standard. This can be found in the local Human Resources Office.
#
# Physical Requirements:
#
# Eligible applicants must be physically and mentally able to perform efficiently the essential functions of the position, with or without reasonable accommodation, without hazard to themselves or others.
# Depending on the essential duties of a specific position, usable vision, color vision, hearing or speech may be required.
#
# however, in most cases, a specific physical condition or impairment of a specific function may be compensated for by the satisfactory use of a prosthesis or mechanical aid.
#
# Moderate carrying and lifting (15-44 pounds); Straight pulling and pushing (0.5 hours); Reaching above shoulder; Use of fingers; Walking (4 hours); Standing (4 hours); Kneeling (0.5 hours); Depth perception; Ability to distinguish basic colors; Hearing (aid may be permitted).; Mental and emotional stability.
#
# Environmental Factors:
# Working closely with others and working alone.
#
# ["Working in Primary Care, Medical-Surgical, Emergency Room (ER), and Intensive Care Unit (ICU), Clinical Deployment Team (CDT) staff will be allocated among 18 networks for a total of 20 full-time employees per network, including 11 Registered Nurses (RNs), 2 Licensed Practical Nurses (LPNs) or Licensed Vocational Nurses (LVNs), 5 providers (including Medical Doctors, Doctors of Osteopathic Medicine, and Advanced Nurse Practitioners) and 2 Social Workers.
# When they are not deployed, CDT staff will work at an assigned VA facility.
#
# Members of the team must:
#
# Be available to deploy with 72 hours' notice within 2 windows of time per calendar year, for up to a month at a time Work in a high-stress environment, possibly in austere conditions or an emergency setting Treat or provide direct patient care within the requirements of practice/privileges/licensure Participate in CDT training activities and demonstrate readiness to apply professional skills to a range of emergency situations Ensure qualifications and required certifications are maintained, including Basic Life Support (BLS), Advanced Cardiac Life Support (ACLS), or Advanced Trauma Life Support (ATLS) certification Maintain CDT physical readiness requirements, vaccinations, and safety precautions related to infection control Physicians on the CDT may work in one of the following areas: Primary Care - Serve on a Patient Aligned Care Team (PACT) and will be responsible for providing medical care in an outpatient setting following PACT principles.
# May provide medical care using Telehealth for remote patients or travel to other outpatient clinics to cover provider shortage. The patient population ranges from adult to geriatrics. Diagnose, treat, and manage a panel of patients. Provide comprehensive patient-centered primary medical care.
#
# VA offers a comprehensive total rewards package:
#
# VHA
#
# Physician Total Rewards Work Schedule:
# Monday - Friday 7:00 am - 4:30 pm. May vary depending on deployment and/or assigned facility needs.
#
# May vary depending on deployment and/or assigned facility needs Compressed/Flexible:
#
# Available Telework:
#
# Available Travel:
# Up to 50% may be required
#
# Virtual:
# This is not a virtual position.
#
# Relocation/Recruitment Incentives (Sign-on Bonus): NOT Authorized EDRP Authorized: This position is eligible for the Education Debt Reduction Program (EDRP), a student loan payment reimbursement program.
#
# You must meet specific individual eligibility requirements in accordance with
# VHApolicy and submit your EDRP application within four months of appointment.
#
# Approval, award amount (up to $200,000) and eligibility period (one to five years) are determined by the
# VHAEducation Loan Repayment Services program office after complete review of the EDRP application.
# Contact and , the EDRP Coordinator for questions/assistance. Learn more.
#
# Permanent Change of Station (PCS):
# NOT Authorized PCS Appraised Value Offer (AVO): NOT
#
# Authorized Pay:
# Competitive salary, annual performance bonus, regular salary increases
# Paid Time Off: 50-55 days of annual paid time offer per year (26 days of annual leave, 13 days of sick leave, 11 paid Federal holidays per year and possible 5 day paid absence for CME)
#
# Retirement:
# Traditional federal pension (5 years vesting) and federal 401K with up to 5% in contributions by VA Insurance: Federal health/vision/dental/term life/long-term care (many federal insurance programs can be carried into retirement)
#
# Licensure: 1 full and unrestricted license from any US State or territory
#
# CME:
# Possible $1,000 per year reimbursement (must be full-time with board certification)
#
# Malpractice:
#
# Free liability protection with tail coverage provided Contract: No Physician Employment Contract"] Create a Job Alert for Similar Jobs About Veterans Affairs, Veterans Health Administration The Veterans Health Administration is America's largest integrated health care system, providing care at 1,298 health care facilities, including 171 medical centers and 1,113 outpatient sites of care of varying complexity (VHA outpatient clinics), serving 9 million enrolled Veterans each year.
# Connections working at Veterans Affairs, Veterans Health Administration More Jobs from This Employer #J-18808-Ljbffr
#     relatedLinks:
#         link:
#           http://www.nmanet.org/
#         text:
#           nmanet.org
#         link:
#           https://www.google.com/search?sca_esv=592980130&q=National+Medical+Association&sa=X&ved=0ahUKEwinq6TH_6GDAxUBJzQIHcAcBQ8QmJACCJgN
#         text:
#           See web results for National Medical Association
#     extras:
#         7 days ago
#         Full-time
#         Health insurance
#         Dental insurance
#         Paid time off
#     metadata:
#       postedAt:
#         7 days ago
#       scheduleType:
#         Full-time
#     applyLink:
#       title:
#         Apply on BeBee
#       link:
#         https://us.bebee.com/job/20231215-bb4964d32e63cca59b18d0496fe645dd?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic
#     title:
#       Principal Doctor
#     companyName:
#       WELLHAVEN PETHEALTH WA CLINICAL LLC
#     location:
#         Vancouver, WA
#     via:
#       via Salary.com
#     description:
#       Ask about our Sign-on Bonus and Relocation Support!
#
# WellHaven Pet Health Mill Plain is a four doctor team, small animal, AAHA Accredited hospital seeking an experienced Principal Doctor to lead our team...
#
# Our AAHA hospital is newly built, top-of-the-line, and provides wellness services, routine surgeries, medical appointments, and daycare for canines. Our practice encourages preventative care through preventive based plans to offer clients an easy and affordable way to stay up to date on vaccines, bloodwork, and prophylactic dentals. We are proud to provide full mouth digital radiographs standard with all dental procedures, digital radiography, and a full Idexx suite of in-house lab machines. Our facility offers modern equipment, a cloud-based computer system, a Cubex pharmacy system for controlled drugs, ultrasound, digital radiography including dental radiography, an in-house IDEXX lab suite, rigorous anesthesia monitoring system (BP, EtCO2, SpO2, EKG)
#
# We offer an opportunity to develop deep client relationships through unhurried visits, comprehensive care, and wellness plans. Our goal is for you to enjoy surgery, internal medicine, and keeping the pets happy and healthy. Our team of colleague doctors and staff will support you with every step. Flexibility is key - as we all like to play and enjoy our family lives. You will find that our passion is not only about pets but that we also take care of ourselves and each other.
#
# Job Summary:
#
# ...
#             Be proficient in anesthesia, surgery, dentistry, and current medical practices
#             Create and maintain veterinarians’ schedules to meet client needs according to WellHaven guidelines while proactively planning time off and CE scheduling
#             Responsible for ensuring the practical training of employees
#             Demonstrate exceptional client service
#             Follow all WellHaven protocols and practices
#             Achieve practice priorities
#             Complete medical records that meet practice quality control guidelines
#             Developing Direct Reports
#             Position often requires working weekends and evenings
#         title:
#           Benefits
#         items:
#             Competitive Salary w/ Profit Sharing annually
#             Quarterly Production Bonus with no negative accrual
#             Flexible schedules to meet your individual need
#             Over one month of Paid Time Off (including holidays/sick pay)
#             A flexible CE allowance designed to fit any stage of your career
#             Health Insurance (Medical, Dental, Vision)
#             Health Savings Account with $500 put in yearly
#             Life Insurance
#             DEA and State License coverage
#             Professional liability included
#             401K
#             Health care plans for two pets
#     relatedLinks:
#         link:
#           https://www.google.com/search?sca_esv=592980130&q=WELLHAVEN+PETHEALTH+WA+CLINICAL+LLC&sa=X&ved=0ahUKEwinq6TH_6GDAxUBJzQIHcAcBQ8QmJACCOMN
#         text:
#           See web results for WELLHAVEN PETHEALTH WA CLINICAL LLC
#     extras:
#         Full-time
#         Health insurance
#         Dental insurance
#         Paid time off
#     metadata:
#       scheduleType:
#         Full-time
#     applyLink:
#       title:
#         Apply on Salary.com
#       link:
#         https://www.salary.com/job/wellhaven-pethealth-wa-clinical-llc/principal-doctor/j202212242219538006618?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic
#     title:
#       Permanent | Physician Hematology Oncology
#     companyName:
#       CompHealth
#     location:
#         Longview, WA
#     via:
#       via LinkedIn
#     description:
#       Longview is ideally situated between Seattle, Washington and Portland, Oregon, offering residents a rural lifestyle with year-round opportunities for recreation. It is the largest city in Cowlitz County.
#
# CompHealth has access to the largest bank of temporary and permanent positions nationwide, we will help you find a practice opportunity that truly matches your criteria. This is an exceptional... opportunity to work with a great organization where you can share your skills and expertise.
#
# Contact Madison Tourville madison.tourville@comphealth.com (954) 616-2933.
# • 1 hour from Portland, Oregon; no state income tax
# • 4-day clinic work week; 1 admin day can be done at home
# • Beautiful location close to an international airport; great schools and new homes
# • Physician-focused group
# • Active clinical trials
# • Strong earning potential with the possibility of coming off base salary at any time
# • Sign-on bonus and relocation assistance
# • J-1 and H-1B candidates are welcome to apply
# • Our services are free for you
# • We help negotiate your salary and contract
# • We coordinate interviews and help with licenses
# • Specialized recruiters match your career preferences
# • Experienced support teams take care of every detail
#
# Salary from $450000.00 to $800000.00 annually
#
# Ranges shown should be used as an estimate and are affected by many factors including the critical need of the position, your overall experience and qualifications, and other considerations. Please reach out to your consultant for more information
#     jobHighlights:
#         title:
#           Benefits
#         items:
#             4-day clinic work week; 1 admin day can be done at home
#             Strong earning potential with the possibility of coming off base salary at any time
#             Sign-on bonus and relocation assistance
#             We help negotiate your salary and contract
#             Salary from $450000.00 to $800000.00 annually
#     relatedLinks:
#         link:
#           https://www.google.com/search?sca_esv=592980130&q=CompHealth&sa=X&ved=0ahUKEwinq6TH_6GDAxUBJzQIHcAcBQ8QmJACCKcO
#         text:
#           See web results for CompHealth
#     thumbnail:
#       https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRhXLAiPuBTWBxbJdaoHjgXENxSgwkMIFfaf_5WQrU&s
#     extras:
#         3 days ago
#         Full-time
#     metadata:
#       postedAt:
#         3 days ago
#       scheduleType:
#         Full-time
#     applyLink:
#       title:
#         Apply on LinkedIn
#       link:
#         https://www.linkedin.com/jobs/view/permanent-physician-hematology-oncology-at-comphealth-3787625304?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic
# categories:
#     type:
#       Title
#     param:
#       job_family_1
#     options:
#         text:
#           All
#         text:
#           Doctor
#         value:
#           doctor
#         text:
#           Optometrist
#         value:
#           optometrist
#         text:
#           Physician
#         value:
#           physician
#         text:
#           Medical doctor
#         value:
#           medical doctor
#         text:
#           Locum
#         value:
#           locum
#         text:
#           Surgeon
#         value:
#           surgeon
#         text:
#           Assistant
#         value:
#           assistant
#         text:
#           Gastroenterologist
#         value:
#           gastroenterologist
#         text:
#           Hospitalist
#         value:
#           hospitalist
#         text:
#           Medicine physician
#         value:
#           medicine physician
#         text:
#           Care physician
#         value:
#           care physician
#         text:
#           Anesthesiology
#         value:
#           anesthesiology
#         text:
#           Family medicine
#         value:
#           family medicine
#         text:
#           Hematology
#         value:
#           hematology
#         text:
#           Locums
#         value:
#           locums
#         text:
#           Psychiatrist
#         value:
#           psychiatrist
#         text:
#           Technician
#         value:
#           technician
#         text:
#           Will train
#         value:
#           will train
#         text:
#           Associate veterinarian
#         value:
#           associate veterinarian
#         text:
#           Cardiology
#         value:
#           cardiology
#         text:
#           Coordinator
#         value:
#           coordinator
#         text:
#           Director
#         value:
#           director
#         text:
#           Faculty
#         value:
#           faculty
#         text:
#           General medicine
#         value:
#           general medicine
#         text:
#           Hospitalist physician
#         value:
#           hospitalist physician
#         text:
#           Hygienist
#         value:
#           hygienist
#         text:
#           Locum tenens
#         value:
#           locum tenens
#         text:
#           Mammography technologist
#         value:
#           mammography technologist
#         text:
#           Medical science
#         value:
#           medical science
#         text:
#           Nurse practitioner
#         value:
#           nurse practitioner
#         text:
#           Obstetrics
#         value:
#           obstetrics
#         text:
#           Occupational medicine
#         value:
#           occupational medicine
#         text:
#           Practice physician
#         value:
#           practice physician
#         text:
#           Psychiatry
#         value:
#           psychiatry
#         text:
#           Psychology
#         value:
#           psychology
#         text:
#           Radiation therapist
#         value:
#           radiation therapist
#         text:
#           Veterinary
#         value:
#           veterinary
#     type:
#       Location
#     param:
#       city
#     options:
#         text:
#           All
#         text:
#           Portland, OR
#         value:
#           J3SpfQsLlVSRhdH25rk2HA==
#         text:
#           Vancouver, WA
#         value:
#           -RRZyGOvlVTz45EsEdVWhA==
#         text:
#           Salem, OR
#         value:
#           Y5xLvPz-v1TCVwOP4Ck0-Q==
#         text:
#           Hillsboro, OR
#         value:
#           eeW8Vl8FlVSG7TNqhv8pfQ==
#         text:
#           Wilsonville, OR
#         value:
#           v40kvI1ulVTix7Z9z5Y6Jw==
#         text:
#           Longview, WA
#         value:
#           Fw1pHRRzlFS5Zn--ibNYxg==
#         text:
#           Lake Oswego, OR
#         value:
#           Dc2hbmlzlVQNmKFrxfP4dA==
#         text:
#           Tualatin, OR
#         value:
#           94Jz-f4GlVQiXZr1-SDNfA==
#         text:
#           Battle Ground, WA
#         value:
#           N8SazIm0lVRjo7yQk3cZ-w==
#         text:
#           Clackamas, OR
#         value:
#           81qAcg57lVQvPzJv_ioIWA==
#         text:
#           Happy Valley, OR
#         value:
#           A5SUNBaelVSgkrEe9h0k-g==
#         text:
#           Newberg, OR
#         value:
#           bVJssZ1qlVTLXHF8KHJeQg==
#         text:
#           Woodburn, OR
#         value:
#           QZ9JLiZclVRCzBUT9wqCMw==
#         text:
#           Beaverton, OR
#         value:
#           Y4j4diQIlVQIvayKFc_gEA==
#         text:
#           Gresham, OR
#         value:
#           u2AuXeh1lVQvXc6tGArDnw==
#         text:
#           McKenna, WA
#         value:
#           9YIODlURkVRKvUg1opJQ4Q==
#         text:
#           McMinnville, OR
#         value:
#           o3PJF7dOlVRIz0XbG3BEyg==
#         text:
#           Tigard, OR
#         value:
#           fQgUd-IHlVRfiLQtTG1-2w==
#         text:
#           Tillamook, OR
#         value:
#           Zf2goAXVlFTTT02YSzQoNA==
#         text:
#           Camas, WA
#         value:
#           u7CVNpW8lVRFhgMdWpKPPA==
#         text:
#           Canby, OR
#         value:
#           T7jOdWNklVTU3Rwuq9wPEQ==
#         text:
#           Cornelius, OR
#         value:
#           y5bs59I8lVQ-e1sPzzWRZw==
#         text:
#           Dundee, OR
#         value:
#           DfmChApBlVS8UztL6FJd8A==
#         text:
#           Eagle Creek, OR
#         value:
#           4xJgCj6DlVTmbX6Jl1F01Q==
#         text:
#           Estacada, OR
#         value:
#           uUmU96EsvlRvBV7wDMqZtQ==
#         text:
#           Forest Grove, OR
#         value:
#           x6NFdyQFlVTzEyX3nG0ezg==
#         text:
#           Gladstone, OR
#         value:
#           _9NuISd0lVSAYJoUYH6UpQ==
#         text:
#           Mill City, OR
#         value:
#           P4kh5p2Rv1TyIKAVv3hr9Q==
#         text:
#           North Plains, OR
#         value:
#           qSvXk3wDlVSCRI_xSv-vQg==
#         text:
#           Salmon Creek, WA
#         value:
#           Y2-llcKtlVTqI7pBTiYGZA==
#         text:
#           Seaside, OR
#         value:
#           Z2YOtixhk1Qi_RtU9AxkjQ==
#         text:
#           Silverton, OR
#         value:
#           x-QdwXvgv1RJg0YuWj1l9A==
#         text:
#           Troutdale, OR
#         value:
#           mSDHiGahlVQu6eTPeBDFIQ==
#         text:
#           Astoria, OR
#         value:
#           i_uVCUR7k1S_ihuh8XLd9w==
#         text:
#           Banks, OR
#         value:
#           FYRng-oclVTKW69VUMIfOA==
#         text:
#           Beaver, OR
#         value:
#           kelOAD_O6lRZjmZcXP8qYQ==
#         text:
#           Beavercreek, OR
#         value:
#           vZPSicV7lVRm3sy9NUZ6RA==
#         text:
#           Cloverdale, OR
#         value:
#           CwwiUM3a6lQauaWG-XUctg==
#         text:
#           Damascus, OR
#         value:
#           N2jn5G2clVSJAMjxlU_bkw==
#         text:
#           Dayton, OR
#         value:
#           z3OYWi1ElVSXM74HjWOr2g==
#         text:
#           Fairview, OR
#         value:
#           PfsU0_iilVRWuU08aZyyVQ==
#         text:
#           Gervais, OR
#         value:
#           9XaisUBDlVQDZlQ6hF3XMA==
#         text:
#           La Center, WA
#         value:
#           PcNX-P5LlFTQW5hT8UkkBw==
#         text:
#           Lafayette, OR
#         value:
#           s-hmTF9GlVQqt8BcfOgIKg==
#         text:
#           Manning, OR
#         value:
#           pZP79tfilFRXTuTS-Pm_6Q==
#         text:
#           Molalla, OR
#         value:
#           U66WgG1ilVR-Lcn6PhG6jg==
#         text:
#           Mount Angel, OR
#         value:
#           g98OFP3hv1TDheQNI7f1_A==
#         text:
#           Mulino, OR
#         value:
#           XSU-6FVjlVSIQV0w-zJq2g==
#         text:
#           Orchards, WA
#         value:
#           5aVQOR6wlVRCHEJnOZccLw==
#         text:
#           Oregon City, OR
#         value:
#           pbwTNaZ5lVStlb634_FmIQ==
#         text:
#           Rainier, OR
#         value:
#           0ZzQ7cNrlFQ8H2inWwcdHA==
#         text:
#           Ridgefield, WA
#         value:
#           UeW5EnNNlFT4aD4Ar3VXCQ==
#         text:
#           Rochester, WA
#         value:
#           11QBaRRjkVSPNu0rxmi5mg==
#     type:
#       Date posted
#     param:
#       date_posted
#     options:
#         text:
#           All
#         text:
#           Past day
#         value:
#           today
#         text:
#           Past 3 days
#         value:
#           3days
#         text:
#           Past week
#         value:
#           week
#         text:
#           Past month
#         value:
#           month
#     type:
#       Requirements
#     param:
#       requirements
#     options:
#         text:
#           All
#         text:
#           No degree
#         value:
#           no_degree
#         text:
#           No experience
#         value:
#           no_experience
#         text:
#           Under 3 years of experience
#         value:
#           years3under
#         text:
#           3+ years of experience
#         value:
#           years3plus
#     type:
#       Type
#     param:
#       employment_type
#     options:
#         text:
#           All
#         text:
#           Full-time
#         value:
#           FULLTIME
#         text:
#           Part-time
#         value:
#           PARTTIME
#         text:
#           Contractor
#         value:
#           CONTRACTOR
#         text:
#           Internship
#         value:
#           INTERN
#     type:
#       Company type
#     param:
#       industry.id
#     options:
#         text:
#           All
#         text:
#           Finance
#         value:
#           /business/naics2007/52
#         text:
#           Health Care
#         value:
#           /business/naics2007/62
#         text:
#           Staffing
#         value:
#           /business/naics2007/5613
#         text:
#           Retail
#         value:
#           /business/naics2007/44
#         text:
#           Education
#         value:
#           /business/naics2007/61
#         text:
#           Manufacturing
#         value:
#           /business/naics2007/31
#     type:
#       Employer
#     param:
#       organization_mid
#     options:
#         text:
#           All
#         text:
#           UnitedHealth Group
#         value:
#           /m/060jqm
#         text:
#           CompHealth
#         value:
#           /g/11fy1m_cb6
#         text:
#           AMN Healthcare
#         value:
#           /m/03p1h8m
#         text:
#           Legacy Health
#         value:
#           /m/05b_bhj
#         text:
#           All Medical Personnel
#         value:
#           /g/11g9n86zrm
#         text:
#           HDA MD Staff
#         value:
#           /g/11t9jrrlvp
#         text:
#           Lap of Love
#         value:
#           /m/013cc_sh
#         text:
#           MPLT Healthcare
#         value:
#           /g/11k5c1kfft
#         text:
#           ICON Medical Network
#         value:
#           /g/11dxpxh9sn
#         text:
#           Ochsner Health System
#         value:
#           /m/0flm88
#         text:
#           OneStaff Medical
#         value:
#           /g/11fy246xcb
#         text:
#           Optum
#         value:
#           /g/11h0vqn2y6
#         text:
#           PeaceHealth
#         value:
#           /m/0vptgcy
#         text:
#           STAFF CARE
#         value:
#           /m/09n23sq
#         text:
#           The Delta Companies
#         value:
#           /g/11g9n0kss1
#         text:
#           United States Air Force
#         value:
#           /m/02rjqfl
#         text:
#           University of Western States
#         value:
#           /m/05l08r
#         text:
#           WellHaven PetHealth LLC
#         value:
#           /g/11fhqlrl8t
#         text:
#           Ansible Government Solutions
#         value:
#           /g/11tg7f1p82
#         text:
#           Britt Medical Search
#         value:
#           /g/11sk8npjy7
#         text:
#           CURAtive
#         value:
#           /g/11j6r3_lk5

# %%
next(client.dataset(run["defaultDatasetId"]).iterate_items())
# Out:
# {'searchQuery': {'term': 'Teacher',
#   'page': 1,
#   'type': 'SEARCH',
#   'domain': 'google.com',
#   'countryCode': 'US',
#   'languageCode': None,
#   'locationUule': None,
#   'resultsPerPage': 10},
#  'url': 'https://www.google.com/search?ibp=htl;jobs&q=Teacher',
#  'hasNextPage': True,
#  'googleJobs': [{'title': 'Child Care Teacher',
#    'companyName': 'Bright Horizons Family Solutions',
#    'location': '  Gaithersburg, MD   ',
#    'via': 'via Bright Horizons Careers',
#    'description': 'Imagine your future as a teacher with a world-class team where you make a difference for children every day. Imagine learning from experts in your field, and having the opportunity to earn your college degree – for free. Imagine it all as a Bright Horizons Teacher.\n\nFull-time positions now available with Infants and Toddlers at our Bright Horizons at Discovery Meadows location in Gaithersburg... Maryland.\n\nA Bright Horizons Career Includes:\n• Flexible scheduling\n• Medical, dental, and vision insurance\n• 401(k) plan\n• Paid time off\n• Referral bonus\n• Career development and FREE college degrees through our Horizons Teacher Degree Program\n• Benefits vary based on full-time/part-time status\n\nAs a Child Care Teacher, you will:\n• Create and lead activities based on your observations of the children’s interests and needs.\n• Communicate daily with parents. Document and share the important milestones in their child’s day.\n• Keep the classroom safe and clean by following important procedures and guidelines.\n\nRequirements:\n\nCandidates must pass required state and company background checks, and meet state and company minimum education and experience requirements:\n• At least 18 years of age with a high school diploma or GED required\n• CDA, or AA or higher ECE degree preferred\n• At least six months of experience working in child care, daycare, or preschool preferred\n• Must have MD 90 hour Certification to meet MD licensing requirements.\n\nExplore your passion for early learning; pursue your purpose as a teacher, and enjoy the possibilities of all the places a Bright Horizons career can take you – in a workplace dedicated to diversity, equity, and inclusion; where you can be you. Come build a brighter future at one of FORTUNE’s “100 Best Companies to Work For.” Apply today!\n\nOur competitive Teacher salaries range from $20.35 - $25.35 per hour. Salary is determined by your level of education and experience in Early Childhood Education or a related field.\n\nCompensation Range: $20.75 - $25.35 /hr\n\nHAVING TECHNICAL ISSUES WITH YOUR APPLICATION?\n\nContact us at bhrecruit@brighthorizons.com or 855-877-6866\n\nBright Horizons is dedicated to creating a workforce that promotes and supports diversity and inclusion. We provide equal employment opportunities to all individuals without discrimination. Bright Horizons complies with the laws and regulations set forth in the following EEO is the Law Poster: EEO – English and EEO – Spanish along with information on the Family and Medical Leave Act (FMLA) and Employee Polygraph Protection Act (EPPA).\n\nApplicants requiring a reasonable accommodation for any part of the application and hiring process should contact the recruitment helpdesk at 855-877-6866 or bhrecruit@brighthorizons.com. Determinations on requests for reasonable accommodation will be made on a case-by-case basis',
#    'jobHighlights': [{'title': 'Qualifications',
#      'items': ['Candidates must pass required state and company background checks, and meet state and company minimum education and experience requirements:',
#       'At least 18 years of age with a high school diploma or GED required',
#       'Must have MD 90 hour Certification to meet MD licensing requirements']},
#     {'title': 'Responsibilities',
#      'items': ['Create and lead activities based on your observations of the children’s interests and needs',
#       'Communicate daily with parents',
#       'Document and share the important milestones in their child’s day',
#       'Keep the classroom safe and clean by following important procedures and guidelines']},
#     {'title': 'Benefits',
#      'items': ['Flexible scheduling',
#       'Medical, dental, and vision insurance',
#       '401(k) plan',
#       'Paid time off',
#       'Referral bonus',
#       'Career development and FREE college degrees through our Horizons Teacher Degree Program',
#       'Benefits vary based on full-time/part-time status',
#       'Our competitive Teacher salaries range from $20.35 - $25.35 per hour',
#       'Salary is determined by your level of education and experience in Early Childhood Education or a related field',
#       'Compensation Range: $20.75 - $25.35 /hr']}],
#    'relatedLinks': [{'link': 'http://www.brighthorizons.com/',
#      'text': 'brighthorizons.com'},
#     {'link': 'https://www.google.com/search?sca_esv=592703979&q=Bright+Horizons+Family+Solutions&sa=X&ved=0ahUKEwjU1KLx0J-DAxWDFFkFHejgBvYQmJACCNoJ',
#      'text': 'See web results for Bright Horizons Family Solutions'}],
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTSlMbSIrChbEK9ru__ZUY5_2sX57DORkZLYgbXPzk&s',
#    'extras': ['10 days ago',
#     'Full-time and Part-time',
#     'Health insurance',
#     'Dental insurance',
#     'Paid time off'],
#    'metadata': {'postedAt': '10 days ago',
#     'scheduleType': 'Full-time and Part-time'},
#    'applyLink': {'title': '.nFg2eb{font-weight:500}.Bi6Ddc{font-weight:500}Apply on Bright Horizons Careers',
#     'link': 'https://careers.brighthorizons.com/us/en/job/JR-093100/Child-Care-Teacher?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}},
#   {'title': 'FACULTY MSD - Teacher',
#    'companyName': 'State of Maryland - MD School for Deaf - Columbia - Educational Svc.',
#    'location': '  Annapolis, MD   ',
#    'via': 'via JobAps',
#    'description': "Introduction\n\nAnticipated openings for the 2021-2022 School Year.\n\nMaryland School for the Deaf (MSD) is a diverse, bilingual community who in partnership with families, provides an equitable and exemplary education in a nurturing, engaging, and challenging environment to ensure our students achieve personal excellence and become lifelong learners.\n\nLOCATION OF POSITION\n\nMSD, Columbia Campus, 8169 Old Montgomery Road, Ellicott City, MD 21043\n\nMain Purpose of Job\n\nTo develop and implement a bilingual educational program for Deaf students in a language accessible environment as well as provide an enriched bicultural environment conducive to the development of the optimal social and emotional growth of Deaf students. To provide a language enriched environment through use of sign language and printed word to meet the varied needs of Deaf students.\n\nPOSITION DUTIES\n\nAssess and teach Deaf students including the implementation of the Maryland College and Career-Ready Standards and the... development of IEPs.  Create and maintain a classroom conducive to learning.  Prepare solid lesson plans based on student assessments and data, and teach lessons using the best practices of bilingual pedagogy and differentiated instruction.  Implement pedagogical best practices in closing the achievement gap, and implementing equitable and unbiased practices in the classroom. Design and make materials to facilitate student learning.  Develop IEPs and write quarterly progress reports; maintain lesson plan book, grade book, portfolios, unit plans, daily attendance, emergency classroom lesson plans.  Utilize effective classroom management for optimal learning including managing student behavior; model appropriate behavior and promote self-control.  Collect data and follow individualized planning.\n\nMINIMUM QUALIFICATIONS\n\nEducation:  Bachelor's degree required.\n\nCandidates must be eligible to apply for or be willing to obtain certification by the Maryland State Department of Education within prescribed amount of time.  Fluency in American Sign Language and written English required.  Knowledge of the Deaf culture, Deaf Education, students with additional disabilities and ability to teach students on different levels and with varying educational and language acquisition backgrounds is required.\n\nDESIRED OR PREFERRED QUALIFICATIONS\n\nMaster's degree in Education or Special Education of Deaf students, Maryland State Department of Education Certification\n\nSPECIAL REQUIREMENTS\n\nNew hires are subject to a criminal background investigation at their own expense.  (Maryland Code, Family Law Article 1, Sections 5-560-568)\n\nCandidates will need to provide three letters of recommendation with their application.\n\nSELECTION PROCESS\n\nApplications will be prescreened before candidates are invited to an interview.  As an equal opportunity employer, MSD is committed to recruiting, retaining, and promoting employees who are reflective of the State's diversity.\n\nBENEFITS\n\nSTATE OF MARYLAND BENEFITS\n\n \n\nFURTHER INSTRUCTIONS\n\nOnline application process is STRONGLY preferred. If you are unable to apply online or if you encounter difficulty, you may submit via mail, e-mail, fax, or deliver in person before the closing date and time.  Please include your name and recruitment number on any documentation to ensure timely processing.  Resumes will NOT be accepted in lieu of completing the online or paper application.  Additional or supplemental information must be submitted by the closing date and time.  A copy of your college transcripts must accompany your application.  The preferred method to receive transcripts and additional information is for them to be uploaded.  Application inquiries or supplemental information can be directed to the following:\n\nMailing Address: Maryland School for the Deaf Recruitment Department, P. O. Box 894, Columbia, MD 21044\n\nE-mail: emily.hicks@msd.edu\n\nPhone: 410-696-3031, TTY User ...
#    'jobHighlights': [{'items': ["Introduction\n\nAnticipated openings for the 2021-2022 School Year.\n\nMaryland School for the Deaf (MSD) is a diverse, bilingual community who in partnership with families, provides an equitable and exemplary education in a nurturing, engaging, and challenging environment to ensure our students achieve personal excellence and become lifelong learners.\n\nLOCATION OF POSITION\n\nMSD, Columbia Campus, 8169 Old Montgomery Road, Ellicott City, MD 21043\n\nMain Purpose of Job\n\nTo develop and implement a bilingual educational program for Deaf students in a language accessible environment as well as provide an enriched bicultural environment conducive to the development of the optimal social and emotional growth of Deaf students. To provide a language enriched environment through use of sign language and printed word to meet the varied needs of Deaf students.\n\nPOSITION DUTIES\n\nAssess and teach Deaf students including the implementation of the Maryland College and Career-Ready Standards and the... development of IEPs.  Create and maintain a classroom conducive to learning.  Prepare solid lesson plans based on student assessments and data, and teach lessons using the best practices of bilingual pedagogy and differentiated instruction.  Implement pedagogical best practices in closing the achievement gap, and implementing equitable and unbiased practices in the classroom. Design and make materials to facilitate student learning.  Develop IEPs and write quarterly progress reports; maintain lesson plan book, grade book, portfolios, unit plans, daily attendance, emergency classroom lesson plans.  Utilize effective classroom management for optimal learning including managing student behavior; model appropriate behavior and promote self-control.  Collect data and follow individualized planning.\n\nMINIMUM QUALIFICATIONS\n\nEducation:  Bachelor's degree required.\n\nCandidates must be eligible to apply for or be willing to obtain certification by the Maryland State Department of Education within prescribed amount of time.  Fluency in American Sign Language and written English required.  Knowledge of the Deaf culture, Deaf Education, students with additional disabilities and ability to teach students on different levels and with varying educational and language acquisition backgrounds is required.\n\nDESIRED OR PREFERRED QUALIFICATIONS\n\nMaster's degree in Education or Special Education of Deaf students, Maryland State Department of Education Certification\n\nSPECIAL REQUIREMENTS\n\nNew hires are subject to a criminal background investigation at their own expense.  (Maryland Code, Family Law Article 1, Sections 5-560-568)\n\nCandidates will need to provide three letters of recommendation with their application.\n\nSELECTION PROCESS\n\nApplications will be prescreened before candidates are invited to an interview.  As an equal opportunity employer, MSD is committed to recruiting, retaining, and promoting employees who are reflective of the State's diversity.\n\nBENEFITS\n\nSTATE OF MARYLAND BENEFITS\n\n \n\nFURTHER INSTRUCTIONS\n\nOnline application process is STRONGLY preferred. If you are unable to apply online or if you encounter difficulty, you may submit via mail, e-mail, fax, or deliver in person before the closing date and time.  Please include your name and recruitment number on any documentation to ensure timely processing.  Resumes will NOT be accepted in lieu of completing the online or paper application.  Additional or supplemental information must be submitted by the closing date and time.  A copy of your college transcripts must accompany your application.  The preferred method to receive transcripts and additional information is for them to be uploaded.  Application inquiries or supplemental information can be directed to the following:\n\nMailing Address: Maryland School for the Deaf Recruitment Department, P. O. Box 894, Columbia, MD 21044\n\nE-mail: emily.hicks@msd.edu\n\nPhone: 410-696- ...
#    'relatedLinks': [{'link': 'https://www.google.com/search?sca_esv=592703979&q=State+of+Maryland+-+MD+School+for+Deaf+-+Columbia+-+Educational+Svc.&sa=X&ved=0ahUKEwjU1KLx0J-DAxWDFFkFHejgBvYQmJACCI8K',
#      'text': 'See web results for State of Maryland - MD School for Deaf - Columbia - Educational Svc.'}],
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRCs0SQlB8vCG4TRIwn5OltTaS-sN2n_dSs3lFevkJj9GsChFmPIv1jew&s',
#    'extras': ['8 days ago', 'Full-time'],
#    'metadata': {'postedAt': '8 days ago', 'scheduleType': 'Full-time'},
#    'applyLink': {'title': 'Apply on JobAps',
#     'link': 'https://jobapscloud.com/MD/sup/bulpreview.asp?R1=21&R2=009009&R3=0002&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}},
#   {'title': 'Resource Teacher- AVID Coordinator- Southwest Academy',
#    'companyName': 'Baltimore County Public Schools',
#    'location': '  Towson, MD   ',
#    'via': 'via ZipRecruiter',
#    'description': 'Position Type:\nTEACH - SECONDARY/RESOURCE TEACHER-MID SCHL (T24900\n...\nDate Posted:\n12/14/2023\n\nLocation:\nSOUTHWEST ACADEMY (015501)\n\nClosing Date:\n12/21/2023BALTIMORE COUNTY PUBLIC SCHOOLS\n\nJOB TITLE: Resource Teacher-AVID Coordinator (10-month)\n\nREPORTS TO: Principal\n\nDEFINITION: The primary role of the school-based resource teacher is to provide in-house expertise, service, and support in curriculum implementation for the school. Provides a variety of services to include professional development, data analysis, and planning for instruction to support the academic programs. The position will lead the Advancement Via Individual Determination (AVID) site team; maintain communication with parents, students, administration, content area teachers, department chairs, school counselors, and professional development teachers regarding the AVID program and its potential to impact students\' school-wide. Serves as the program\'s liaison to the Office of College and Career Readiness. Performs other duties as assigned.\n\nEXAMPLES OF DUTIES:\n• Coordinates school-wide AVID program implementation and serves as the program\'s liaison with the Office of College and Career Readiness. Ensures AVID curriculum aligns with the systems strategic plan.\n• Leads and plans site team meetings with administrative staff, school counselors, department chairs, elective teachers, content teachers, professional development teachers, students, parents, and community members.\n• Serves as instructional leader sharing AVID methodologies and Writing, Inquiry, Collaboration, Organization, and Reading (WICOR) strategies school-wide.\n• Manages the program, AVID elective teachers, other site team members, tutors, and AVID students.\n• Recruits and interviews students. Analyzes and monitors student data and progress. Writes reports, maintains documentation, and annually compiles the AVID Certification Self-Study e-binder for AVID certification.\n• Creates advertising material to promote AVID. Collects, maintains, and inputs data as required by the National AVID Center.\n• Establishes rapport with tutors grounded in mutual respect and trust. Trains and supervises AVID tutors.\n• Initiates and expands connections with colleges and universities. Arranges for speakers from local colleges/universities and community leaders.\n• Maintains the AVID budget for supplies and materials and ensures funds for the AVID College Field Trip Initiative.\n• Advises students and fosters community relations. Plans and presents parent nights, Family Fun nights, and AVID informational sessions. Maintains and updates social media and websites.\n• Monitors AVID student progress and utilizes AVID probationary process, as needed.\n• Mentors and co-plans with AVID elective teachers. Facilitates requests from other teachers to model AVID teaching techniques. Demonstrates effective classroom management and discipline.\n• Organizes field trips to colleges/universities and places of historical, cultural, educational, and professional interest for all AVID elective classes.\n• Performs other duties as assigned.\n\nMINIMUM QUALIFICATIONS:\n\nEducation, Training and Experience:\nGraduation from an accredited college or university with a bachelor\'s degree in a field related to the assignment, plus three years of successful teaching experience which includes experience in planning and implementing professional development. Master\'s degree preferred.\n\nAVID Center Certification and experience as an AVID elective teacher or AVID site team coordinator is preferred.\n\nLicenses and Certificates:\nPossession of, or eligibility for, a Maryland Professional Certificate is required.\n\nMaryland Advanced Professional certificate preferred.\n\nKnowledge, Skills, and Abilities:\nStrong curriculum content.\nKnowledge of effective instructional practices in elementary/middle; demonstration of strong communication and human relations skills; demonstration of effective organiza ...
#    'jobHighlights': [{'title': 'Qualifications',
#      'items': ["Graduation from an accredited college or university with a bachelor's degree in a field related to the assignment, plus three years of successful teaching experience which includes experience in planning and implementing professional development",
#       'Possession of, or eligibility for, a Maryland Professional Certificate is required',
#       'Strong curriculum content',
#       'Knowledge of effective instructional practices in elementary/middle; demonstration of strong communication and human relations skills; demonstration of effective organization and communication skills; demonstration of strong computer/technology skills',
#       'If you answer "yes" to any of the criminal background questions you must provide a written explanation',
#       'A copy of your TEACHER CERTIFICATION',
#       'A copy of your TRANSCRIPTS',
#       'A copy of your PRAXIS or other state test scores',
#       'A copy of your MARYLAND IN-SERVICE COURSE SLIPS',
#       'All persons employed by the Baltimore County Public Schools, regular and temporary, are required to be fingerprinted and have a criminal background investigation (per COMAR) completed',
#       'An identification card will be issued which must be shown prior to employment',
#       'Anyone offered employment is required to provide proper identification and documentation of eligibility for employment in the US',
#       'If you have military experience you will be asked to provide a copy of DD214',
#       'Official transcripts for all higher education must be received prior to contract signing',
#       'Some positions will require employees to undergo a physical examination and/or drug testing',
#       'All newly hired personnel must attend a Badges and Benefits session',
#       'Additional job verification will be required for salary credit']},
#     {'title': 'Responsibilities',
#      'items': ['DEFINITION: The primary role of the school-based resource teacher is to provide in-house expertise, service, and support in curriculum implementation for the school',
#       'Provides a variety of services to include professional development, data analysis, and planning for instruction to support the academic programs',
#       "The position will lead the Advancement Via Individual Determination (AVID) site team; maintain communication with parents, students, administration, content area teachers, department chairs, school counselors, and professional development teachers regarding the AVID program and its potential to impact students' school-wide",
#       'Performs other duties as assigned',
#       "Coordinates school-wide AVID program implementation and serves as the program's liaison with the Office of College and Career Readiness",
#       'Ensures AVID curriculum aligns with the systems strategic plan',
#       'Leads and plans site team meetings with administrative staff, school counselors, department chairs, elective teachers, content teachers, professional development teachers, students, parents, and community members',
#       'Serves as instructional leader sharing AVID methodologies and Writing, Inquiry, Collaboration, Organization, and Reading (WICOR) strategies school-wide',
#       'Manages the program, AVID elective teachers, other site team members, tutors, and AVID students',
#       'Recruits and interviews students',
#       'Analyzes and monitors student data and progress',
#       'Writes reports, maintains documentation, and annually compiles the AVID Certification Self-Study e-binder for AVID certification',
#       'Creates advertising material to promote AVID',
#       'Collects, maintains, and inputs data as required by the National AVID Center',
#       'Establishes rapport with tutors grounded in mutual respect and trust',
#       'Trains and supervises AVID tutors',
#       'Initiates and expands connections with colleges and universities',
#       'Arranges for speakers from local colleges/universities and community leaders',
#       'Maintains the AVID budget for supplies and materials and ensures funds for the AVID College Field Trip Initiative',
#       'Advises students and fosters community relations',
#       'Plans and presents parent nights, Family Fun nights, and AVID informational sessions',
#       'Maintains and updates social media and websites',
#       'Monitors AVID student progress and utilizes AVID probationary process, as needed',
#       'Mentors and co-plans with AVID elective teachers',
#       'Facilitates requests from other teachers to model AVID teaching techniques',
#       'Demonstrates effective classroom management and discipline',
#       'Organizes field trips to colleges/universities and places of historical, cultural, educational, and professional interest for all AVID elective classes',
#       'In the office, work includes the operation of office equipment and personal computers']},
#     {'title': 'Benefits',
#      'items': ['FLSA Status: Exempt',
#       'Eligible for membership in the Maryland State Retirement System']}],
#    'relatedLinks': [{'link': 'https://www.google.com/search?sca_esv=592703979&q=Baltimore+County+Public+Schools&sa=X&ved=0ahUKEwjU1KLx0J-DAxWDFFkFHejgBvYQmJACCNUK',
#      'text': 'See web results for Baltimore County Public Schools'}],
#    'extras': ['7 days ago', 'Full-time'],
#    'metadata': {'postedAt': '7 days ago', 'scheduleType': 'Full-time'},
#    'applyLink': {'title': 'Apply on ZipRecruiter',
#     'link': 'https://www.ziprecruiter.com/c/Baltimore-County-Public-Schools/Job/Resource-Teacher-AVID-Coordinator-Southwest-Academy/-in-Towson,MD?jid=5f05fc5e9b2e551d&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}},
#   {'title': 'IMMEDIATE: Long Term Substitute Teacher, Special Education (HSM...',
#    'companyName': 'Montgomery County Public Schools',
#    'location': '  Germantown, MD   ',
#    'via': 'via LinkedIn',
#    'description': 'Summary Description\n\nUnder direction of the school principal and special education supervisor, the special education teacher provides direct instruction and instructional support to students with disabilities and works in collaboration with the general education teacher. Monitors and evaluates outcomes for students with disabilities. Assists in the development of Individualized Education Programs... (IEP).\n\nCertificate License\n\nMeets Maryland State Department of Education certification requirements for Standard Professional Certification I (SPC I) in special education. Certification in a content area is desirable.\n\nJob\n\nSpecial Education\n\nOrganization\n\nLake Seneca Elementary School\n\nPrimary Location\n\nGermantown\n\nSchedule\n\nFull-time\n\nWorking Months\n\n10\n\nShift\n\nDay Job\n\nJob Posting\n\nSep 1, 2023, 3:37:42 PM\n\nKNOWLEDGE, SKILLS, And ABILITIES\n\nKnowledge of the Montgomery County Public Schools (MCPS) curriculum for the grade/content range of the position, MCPS special education program. Thorough knowledge of IEP, learning theory, differentiated instruction, data collection, best instructional practices, research-based reading instruction, multicultural education, assessments. Thorough knowledge in methods of teaching elementary math if seeking an elementary position. Every Student Succeeds Act (ESSA 2015), Individuals with Disabilities Act (IDEA 2004), and state and federal policies and procedures related to special education. Ability to provide instructional support. Works well with students with disabilities, teachers, and parents/guardians of students with disabilities. Ability to appropriately adapt instructional programs and materials. Excellent communication skills. Knowledge of and the ability to apply the six performance standards established for the Montgomery County Public Schools (MCPS) Teacher Professional Growth System (TPGS).\n\nEDUCATION, TRAINING, And EXPERIENCE\n\nBachelors degree from an accredited college or university in special education.. Fluent in learning theory, differentiated instruction, developmental reading, child development, applied behavior analysis, and assessment required. Student teaching in the specific area of exceptionality or two years teaching experience at level appropriate to assignment (elementary or secondary). Other combinations of applicable education, training, and experience which provide the knowledge, abilities, and skills necessary to perform effectively in the position may be considered',
#    'jobHighlights': [{'title': 'Qualifications',
#      'items': ['Meets Maryland State Department of Education certification requirements for Standard Professional Certification I (SPC I) in special education',
#       'Knowledge of the Montgomery County Public Schools (MCPS) curriculum for the grade/content range of the position, MCPS special education program',
#       'Thorough knowledge of IEP, learning theory, differentiated instruction, data collection, best instructional practices, research-based reading instruction, multicultural education, assessments',
#       'Thorough knowledge in methods of teaching elementary math if seeking an elementary position',
#       'Every Student Succeeds Act (ESSA 2015), Individuals with Disabilities Act (IDEA 2004), and state and federal policies and procedures related to special education',
#       'Ability to appropriately adapt instructional programs and materials',
#       'Excellent communication skills',
#       'Knowledge of and the ability to apply the six performance standards established for the Montgomery County Public Schools (MCPS) Teacher Professional Growth System (TPGS)',
#       'Bachelors degree from an accredited college or university in special education.',
#       'Fluent in learning theory, differentiated instruction, developmental reading, child development, applied behavior analysis, and assessment required',
#       'Student teaching in the specific area of exceptionality or two years teaching experience at level appropriate to assignment (elementary or secondary)',
#       'Other combinations of applicable education, training, and experience which provide the knowledge, abilities, and skills necessary to perform effectively in the position may be considered']},
#     {'title': 'Responsibilities',
#      'items': ['Under direction of the school principal and special education supervisor, the special education teacher provides direct instruction and instructional support to students with disabilities and works in collaboration with the general education teacher',
#       'Monitors and evaluates outcomes for students with disabilities',
#       'Assists in the development of Individualized Education Programs (IEP)']}],
#    'relatedLinks': [{'link': 'https://www.google.com/search?sca_esv=592703979&q=Montgomery+County+Public+Schools&sa=X&ved=0ahUKEwjU1KLx0J-DAxWDFFkFHejgBvYQmJACCJkL',
#      'text': 'See web results for Montgomery County Public Schools'}],
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTgvFj2C6hPAtPfllY8hPfQxgtePiT1_pFyeWgqUWA&s',
#    'extras': ['Full-time'],
#    'metadata': {'scheduleType': 'Full-time'},
#    'applyLink': {'title': 'Apply on LinkedIn',
#     'link': 'https://www.linkedin.com/jobs/view/immediate-long-term-substitute-teacher-special-education-hsm-lake-seneca-es-fulltime-at-montgomery-county-public-schools-3710376346?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}},
#   {'title': 'City Teaching Alliance Resident 2024 (for Aspiring Teachers!)',
#    'companyName': 'City Teaching Alliance',
#    'location': '  Washington, DC   ',
#    'via': 'via LinkedIn',
#    'description': "Current Deadline – January 16, 2024\n\nProgram Overview...\n\nCity Teaching Alliance is a four-year teacher training and certification program that works to end educational inequity in schools by improving teacher quality and preparing a pipeline of high-performing career teachers. Educators who complete the City Teaching Alliance program are among the most expert and results-oriented in the nation because we provide the best teacher preparation available.\n\nProgram Benefits\n\nResidency Year\n\nA full year to work as a co-teacher in urban classrooms under the guidance of our expert faculty, receiving regular feedback as you develop your skills and prove your effectiveness. The residency year gives you practice time in anticipation of your career as a teacher.\n\nSigning Bonus\n\nCity Teaching Alliance is pleased to offer all incoming Cohort 2024 residents a $1,000 signing bonus!\n\nTransitional Assistance\n\nCity Teaching Alliance will be offering all incoming Cohort 2024 residents $2,000 in transitional assistance to help ease the transition to the classroom. Cohort 2024 residents can also apply for additional needs-based transitional funding, up to $4,000 total.\n\nMaster's Degree\n\nOver the first two years in the program, City Teaching Alliance participants earn a master’s from the American University School of Education while working alongside experienced teachers during year one, and managing their own classroom in their second year.\n\nCoaching and Mentoring\n\nFour years of mentoring and support are tailored to your needs—from coaches and peers—and available longer than any other preparation program. This includes three full years of one-on-one coaching to ensure you develop as an effective teacher.\n\nPlacement Program\n\nAt the start of your second year, you will be a full-time teacher of record in one of our partner districts, where effective, experienced teachers can earn over $100,000 per year later in their careers. We also provide school placement to all participants.\n\nMeaningful Work\n\nOur program develops and prepares highly qualified teachers for the purpose of combating racial and socioeconomic inequality. We train those in our program to become highly effective teachers who are committed to teaching students in the districts that need them most and empowering every child through learning.\n\nCity Teaching Alliance seeks passionate individuals who are ready to become effective teachers for students in urban communities to fill an immediate need for teachers in Elementary Education, Secondary Math, and Secondary Literacy. We currently place teachers in Washington DC, Baltimore, Dallas, and Philadelphia (our newest location!)\n\nDuring the first year of our program, participants receive a stipend from City Teaching Alliance between $30,000 - $38,600, depending on the city of their placement. In addition, participants will receive books, materials, and healthcare benefits. Starting the second year, participants are employed as full-time teachers and begin to receive a full salary ($50,000 - $60,000) in addition to their eligibility for monetary education awards (AmeriCorps Segal Award, valued at $6,895 and the TEACH grant valued at $3,772) and benefits as an employee of the school district or charter network where they are placed.\n\nStart your application to join our next cohort in a few easy steps, provided you meet the following minimum requirements:\n\n· Earn an undergraduate degree by June 2024 (or June 2025 for early undergraduate applicants)\n\n· A minimum 2.5 undergraduate GPA\n\n· Are a US Citizens, Permanent Resident, or DACA recipient\n\nJob Type: Full-time\n\nStart Date: Mid-June 2024\n\nApply at: https://rb.gy/b2apj\n\nAbout City Teaching Alliance\n\nEmpowering Educators, Transforming Futures\n\nAt City Teaching Alliance, we produce highly effective educators who empower every child through learning. Our teachers become career educators committed to equity and inclusivity, e ...
#    'jobHighlights': [{'title': 'Qualifications',
#      'items': ['Earn an undergraduate degree by June 2024 (or June 2025 for early undergraduate applicants)',
#       'A minimum 2.5 undergraduate GPA',
#       'Are a US Citizens, Permanent Resident, or DACA recipient']},
#     {'title': 'Benefits',
#      'items': ['The residency year gives you practice time in anticipation of your career as a teacher',
#       'City Teaching Alliance is pleased to offer all incoming Cohort 2024 residents a $1,000 signing bonus!',
#       'City Teaching Alliance will be offering all incoming Cohort 2024 residents $2,000 in transitional assistance to help ease the transition to the classroom',
#       'Cohort 2024 residents can also apply for additional needs-based transitional funding, up to $4,000 total',
#       'Over the first two years in the program, City Teaching Alliance participants earn a master’s from the American University School of Education while working alongside experienced teachers during year one, and managing their own classroom in their second year',
#       'At the start of your second year, you will be a full-time teacher of record in one of our partner districts, where effective, experienced teachers can earn over $100,000 per year later in their careers',
#       'During the first year of our program, participants receive a stipend from City Teaching Alliance between $30,000 - $38,600, depending on the city of their placement',
#       'In addition, participants will receive books, materials, and healthcare benefits',
#       'Starting the second year, participants are employed as full-time teachers and begin to receive a full salary ($50,000 - $60,000) in addition to their eligibility for monetary education awards (AmeriCorps Segal Award, valued at $6,895 and the TEACH grant valued at $3,772) and benefits as an employee of the school district or charter network where they are placed',
#       'Salary: Up to $60,000.00 per year',
#       '401(k)',
#       'Dental insurance',
#       'Health insurance',
#       'Paid time off',
#       'Professional development assistance',
#       'Vision insurance']}],
#    'relatedLinks': [{'link': 'https://www.google.com/search?sca_esv=592703979&q=City+Teaching+Alliance&sa=X&ved=0ahUKEwjU1KLx0J-DAxWDFFkFHejgBvYQmJACCOAL',
#      'text': 'See web results for City Teaching Alliance'}],
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSxzoUinhWeLCX_sx-gg-UWkHuzrW1PvphOaMgR1As&s',
#    'extras': ['5 days ago',
#     'Full-time',
#     'Health insurance',
#     'Dental insurance',
#     'Paid time off'],
#    'metadata': {'postedAt': '5 days ago', 'scheduleType': 'Full-time'},
#    'applyLink': {'title': 'Apply on LinkedIn',
#     'link': 'https://www.linkedin.com/jobs/view/city-teaching-alliance-resident-2024-for-aspiring-teachers%21-at-city-teaching-alliance-3782264317?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}},
#   {'title': 'Teacher - Special Education Extensive Autism (2024-2025 School Year)',
#    'companyName': 'Hanover County Public Schools',
#    'location': '  Ashland, VA   ',
#    'via': 'via GovernmentJobs.com',
#    'description': '**This posting is intended to generate a pool of qualified applicants who wish to be considered for vacancies as they develop for the 2024-2025 school year**\n\nGeneral Responsibilities...\nResponsible for providing direct instruction to students with autism and related developmental disabilities. Responsible for assisting with and implementing special education instructional programs, and following state and federal policies regarding special education procedures.\n.\nEssential Duties;\n(These are intended only as illustrations of the various types of work performed. The omission of specific duties does not exclude them from the position if the work is similar, related, or a logical assignment to the position.)\n• Uses a variety of effective instructional strategies and resources individualized to meet students’ needs to promote independence\n• Provides direct instruction and in-class support to students with autism and related developmental disabilities in a variety of both special education and general education settings throughout the school\n• Aligns IEP goals to instructional plans and aligns instructional plans to the SOLs/ASOLs and school curriculum\n• Implements instruction based on the students’ needs in the areas of communication and social skills\n• Differentiates instruction to meet students’ needs\n• Uses a variety of assessment strategies and instruments that are valid and appropriate for the content and for the individual student\n• Collects data related to student’s IEP goals and objectives\n• Analyzes assessment and program data to make data driven decisions and demonstrates ability to adapt teaching materials and strategies based on student data\n• Uses accommodations and modifications as determined by the IEP to support instruction\n• Establishes a climate centered around the student that promotes dignity and respect\n• Implements individual Behavior Intervention Plans, and school-wide Positive Behavior Interventions and Supports consistently\n• Supports students when they engage in challenging behaviors and teaches appropriate replacement behaviors\n• Monitors and documents the progress of each student according to their IEP within federal, state, and division timelines\n• Collaborates and communicates effectively within the school community to promote inclusion and student success\n• Provides clear expectations and guidance for collaborating paraprofessionals\n• Works in a collegial and collaborative manner with administrators, related services personnel, paraprofessionals, other school personnel, and the community\n• Builds positive and professional relationships with parents/guardians through frequent and effective communication concerning students’ progress\n• Adheres to federal and state laws, school policies, and ethical guidelines\n• Perform related work as required.\n\nKnowledge, Skills and Abilities:\nDemonstrates accurate knowledge of evidence based teaching practices (reinforcement, prompting, visual schedules, antecedent based intervention, etc.). Demonstrates accurate knowledge of the learning and behavioral characteristics of the disabilities of the students with whom they work. Demonstrates understanding of functions of behavior and is knowledgeable of interventions matched to each. Experience working in an educational setting with students with autism and/or related developmental disabilities. Experience with a variety of evidence-based instructional practices as well as data collection and its utilization. Specific knowledge of assistive technology, interventions to support communication and social skills development. Familiarity with the Virginia Aligned Standards of Learning, or comparable modified curricula and instruction on Activities of Daily Living. Experience instructing students with extensive support needs in a collaborative setting. Knowledge of special education laws, policies and practices.\n\nEducation and Experience:\nRequired: Bachelors Degree in appropri ...
#    'jobHighlights': [{'title': 'Qualifications',
#      'items': ['Demonstrates accurate knowledge of evidence based teaching practices (reinforcement, prompting, visual schedules, antecedent based intervention, etc.). Demonstrates accurate knowledge of the learning and behavioral characteristics of the disabilities of the students with whom they work',
#       'Experience with a variety of evidence-based instructional practices as well as data collection and its utilization',
#       'Specific knowledge of assistive technology, interventions to support communication and social skills development',
#       'Experience instructing students with extensive support needs in a collaborative setting',
#       'Knowledge of special education laws, policies and practices',
#       'Required: Bachelors Degree in appropriate related field',
#       'Must have a record of successful full-time teaching experience or have demonstrated a successful student teaching placement/internship',
#       'BCBA, BCaBA, RBT certification, or other specific training in the principles of Applied Behavior Analysis',
#       'A comparable amount of training and experience may be substituted for the minimum qualifications',
#       'Special Requirements: Must hold or be eligible for Va',
#       'Teacher License w/ endorsement in Special Ed Adapted Curriculum or Special Ed Intellectual Disabilities',
#       'Must have the use of sensory skills in order to effectively communicate and interact with other employees and the public through the use of the telephone and personal contact',
#       'Frequent walking, standing, lifting up to 50 pounds unassisted, and other physical activities are required',
#       'Movement of students by wheelchairs and other mechanical devices may be required',
#       'Occasional lifting of equipment such as audio-visuals, regular stooping, kneeling, crouching, and reaching and significant pushing, pulling, lifting, grasping, and repetitive motions are also required',
#       'Must be able to effectively use and operate various items of office related equipment, such as, but not limited to a, personal computer, calculator, copier, and fax machine']},
#     {'title': 'Responsibilities',
#      'items': ['Responsible for assisting with and implementing special education instructional programs, and following state and federal policies regarding special education procedures',
#       '(These are intended only as illustrations of the various types of work performed',
#       'Uses a variety of effective instructional strategies and resources individualized to meet students’ needs to promote independence',
#       'Provides direct instruction and in-class support to students with autism and related developmental disabilities in a variety of both special education and general education settings throughout the school',
#       'Aligns IEP goals to instructional plans and aligns instructional plans to the SOLs/ASOLs and school curriculum',
#       'Implements instruction based on the students’ needs in the areas of communication and social skills',
#       'Uses a variety of assessment strategies and instruments that are valid and appropriate for the content and for the individual student',
#       'Collects data related to student’s IEP goals and objectives',
#       'Analyzes assessment and program data to make data driven decisions and demonstrates ability to adapt teaching materials and strategies based on student data',
#       'Uses accommodations and modifications as determined by the IEP to support instruction',
#       'Establishes a climate centered around the student that promotes dignity and respect',
#       'Implements individual Behavior Intervention Plans, and school-wide Positive Behavior Interventions and Supports consistently',
#       'Supports students when they engage in challenging behaviors and teaches appropriate replacement behaviors',
#       'Monitors and documents the progress of each student according to their IEP within federal, state, and division timelines',
#       'Collaborates and communicates effectively within the school community to promote inclusion and student success',
#       'Provides clear expectations and guidance for collaborating paraprofessionals',
#       'Works in a collegial and collaborative manner with administrators, related services personnel, paraprofessionals, other school personnel, and the community',
#       'Builds positive and professional relationships with parents/guardians through frequent and effective communication concerning students’ progress',
#       'Adheres to federal and state laws, school policies, and ethical guidelines',
#       'Perform related work as required',
#       'Demonstrates understanding of functions of behavior and is knowledgeable of interventions matched to each']},
#     {'title': 'Benefits', 'items': ['Salary Scale: Teacher']}],
#    'relatedLinks': [{'link': 'https://www.google.com/search?sca_esv=592703979&q=Hanover+County+Public+Schools&sa=X&ved=0ahUKEwjU1KLx0J-DAxWDFFkFHejgBvYQmJACCKcM',
#      'text': 'See web results for Hanover County Public Schools'}],
#    'extras': ['3 days ago', '50,300–86,583 a year', 'Full-time'],
#    'metadata': {'postedAt': '3 days ago',
#     'scheduleType': 'Full-time',
#     'salary': '50,300–86,583 a year'},
#    'applyLink': {'title': 'Apply on GovernmentJobs.com',
#     'link': 'https://www.governmentjobs.com/jobs/4318645-0/teacher-special-education-extensive-autism-2024-2025-school-year?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}},
#   {'title': 'Elementary School Science Teacher for International School in...',
#    'companyName': 'Ubuntu Pathways',
#    'location': '  New York, NY   ',
#    'via': 'via LinkedIn',
# ...
#    'jobHighlights': [{'title': 'Qualifications',
#      'items': ['Outstanding customer service skills, strong organizational skills, and the ability to multi-task and handle multiple situations effectively',
#       'CPR and First Aid Certification or willingness to obtain',
#       'Meet state specific qualifications for the role or willingness to obtain',
#       'Active Child Development Associate (CDA) Credential (or willing to obtain)',
#       'Physically able to use a computer with basic proficiency, lift a minimum of 40 pounds, and work indoors or outdoors',
#       'Able to assume postures in low levels to allow physical and visual contact with children, see and hear well enough to keep children safe, and engage in physical activity with children',
#       'Read, write, understand, and speak English to communicate with children and their parents in English']},
#     {'title': 'Responsibilities',
#      'items': ["Implement KinderCare's curriculum in a way that is consistent with the unique needs of each child",
#       'Create a safe, nurturing environment where children can play and learn',
#       'Partner and connect with parents, with a shared desire to provide the best care and education for their children',
#       'Support your center’s success; partner with center staff and leadership to achieve goals around enrollment, accreditation, and engagement',
#       'Cultivate positive relationships with families, teachers, state licensing authorities, community contacts and corporate partners']},
#     {'title': 'Benefits',
#      'items': ['Invest in you and your career at KinderCare as you create a world-class experience in our classrooms',
#       'Reward your commitment to our children and families as your journey continues with us',
#       'Know your whole family is supported with discounted child care benefits',
#       'Breathe easy with medical, dental, and vision benefits for your family (and pets, too!)',
#       'Feel supported in your mental health and personal growth with employee assistance programs',
#       'Feel great and thrive with access to health and wellness programs, paid time off and discounts for work necessities, such as cell phones']}],
#    'relatedLinks': [{'link': 'http://www.kindercare.com/',
#      'text': 'kindercare.com'},
#     {'link': 'https://www.google.com/search?sca_esv=592703979&q=KINDERCARE&sa=X&ved=0ahUKEwjU1KLx0J-DAxWDFFkFHejgBvYQmJACCNwO',
#      'text': 'See web results for KINDERCARE'}],
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSFOakCTkKrITB3-glT5XBSVAIVNkY8AgVhi8GnRIrXDWfG0P0pDp0KNCE&s',
#    'extras': ['2 days ago',
#     'Full-time',
#     'No degree mentioned',
#     'Health insurance',
#     'Dental insurance',
#     'Paid time off'],
#    'metadata': {'postedAt': '2 days ago', 'scheduleType': 'Full-time'},
#    'applyLink': {'title': 'Apply on KinderCare Education',
#     'link': 'https://www.kcecareers.com/job/KNOWA0054231218301468TEXTERNALENUS/Teachers-at-Kingstowne-KinderCare?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}}],
#  'categories': [{'type': 'Title',
#    'param': 'job_family_1',
#    'options': [{'text': 'All'},
#     {'text': 'Teacher', 'value': 'teacher'},
#     {'text': 'Substitute teacher', 'value': 'substitute teacher'},
#     {'text': 'Education teacher', 'value': 'education teacher'},
#     {'text': 'Music teacher', 'value': 'music teacher'},
#     {'text': 'Science teacher', 'value': 'science teacher'},
#     {'text': 'Assistant teacher', 'value': 'assistant teacher'},
#     {'text': 'Care teacher', 'value': 'care teacher'},
#     {'text': 'Math teacher', 'value': 'math teacher'},
#     {'text': 'English teacher', 'value': 'english teacher'},
#     {'text': 'Preschool teacher', 'value': 'preschool teacher'},
#     {'text': 'Volunteer', 'value': 'volunteer'},
#     {'text': 'Teacher assistant', 'value': 'teacher assistant'},
#     {'text': 'Lead teacher', 'value': 'lead teacher'},
#     {'text': 'Teacher aide', 'value': 'teacher aide'},
#     {'text': 'Art teacher', 'value': 'art teacher'},
#     {'text': 'Infant teacher', 'value': 'infant teacher'},
#     {'text': 'Kindergarten teacher', 'value': 'kindergarten teacher'},
#     {'text': 'School teacher', 'value': 'school teacher'},
#     {'text': 'Teachers', 'value': 'teachers'},
#     {'text': 'Associate teacher', 'value': 'associate teacher'},
#     {'text': 'Childhood teacher', 'value': 'childhood teacher'},
#     {'text': 'Elementary teacher', 'value': 'elementary teacher'},
#     {'text': 'Faculty', 'value': 'faculty'},
#     {'text': 'High school', 'value': 'high school'},
#     {'text': 'Resource teacher', 'value': 'resource teacher'},
#     {'text': 'Specialist', 'value': 'specialist'},
#     {'text': 'Certified', 'value': 'certified'},
#     {'text': 'Esl teacher', 'value': 'esl teacher'},
#     {'text': 'Facilitator', 'value': 'facilitator'},
#     {'text': 'Grade teacher', 'value': 'grade teacher'},
#     {'text': 'History teacher', 'value': 'history teacher'},
#     {'text': 'Primary teacher', 'value': 'primary teacher'},
#     {'text': 'Resident', 'value': 'resident'},
#     {'text': 'Teaching', 'value': 'teaching'},
#     {'text': 'Academy', 'value': 'academy'},
#     {'text': 'Adjunct faculty', 'value': 'adjunct faculty'},
#     {'text': 'Aide', 'value': 'aide'},
#     {'text': 'Apprenticeship', 'value': 'apprenticeship'},
#     {'text': 'Bilingual', 'value': 'bilingual'},
#     {'text': 'Child', 'value': 'child'},
#     {'text': 'Coach', 'value': 'coach'},
#     {'text': 'Consultant', 'value': 'consultant'},
#     {'text': 'Department head', 'value': 'department head'},
#     {'text': 'Director', 'value': 'director'},
#     {'text': 'Education', 'value': 'education'},
#     {'text': 'Head teacher', 'value': 'head teacher'},
#     {'text': 'Hire', 'value': 'hire'},
#     {'text': 'Instructor', 'value': 'instructor'},
#     {'text': 'Language teacher', 'value': 'language teacher'},
#     {'text': 'Outreach', 'value': 'outreach'},
#     {'text': 'Physics teacher', 'value': 'physics teacher'},
#     {'text': 'School', 'value': 'school'}]},
#   {'type': 'Location',
#    'param': 'city',
#    'options': [{'text': 'All'},
#     {'text': 'Houston, TX', 'value': 'AYWNSLS4QIY7BWXz3gINyg=='},
#     {'text': 'Chicago, IL', 'value': '7cv00DwsDogAwMAJrabgrw=='},
#     {'text': 'New York, NY', 'value': 'Owg_06VPwoli_nfhBo8LyA=='},
#     {'text': 'Las Vegas, NV', 'value': '0X31pIK3voCjebPV5tXMOg=='},
#     {'text': 'St. Louis, MO', 'value': '-Y7t-qm02Idb4Lsiyuo5vg=='},
#     {'text': 'Asheville, NC', 'value': 'CW8PPKmMWYhdOjQGwTHvlA=='},
#     {'text': 'Marietta, GA', 'value': 'XQZHhpYQ9YiB6Y4yxlaHsQ=='},
#     {'text': 'Oklahoma City, OK', 'value': 'gdL4flSKrYedOk_RdBKiMw=='},
#     {'text': 'San Antonio, TX', 'value': 'rw7QBK9YXIa8FqAQO-FWCA=='},
#     {'text': 'Ashburn, VA', 'value': 'V8n8ZvEVtolbPR6xbjHaCQ=='},
#     {'text': 'Ashland, VA', 'value': '8R4evl05sYnlXBonnfI1aw=='},
#     {'text': 'Aurora, CO', 'value': 'myu6IoZYbId45qKLaOBBhA=='},
#     {'text': 'Austin, TX', 'value': 'LwPMoJm1RIZ61WnUS0abXQ=='},
#     {'text': 'Bellevue, WA', 'value': 'QWCmo89rkFRlB9DqglTPug=='},
#     {'text': 'Boston, MA', 'value': 'GzE9DS1l44mg6GIBJL98eA=='},
#     {'text': 'Carmel, ME', 'value': 'z37baMUzrkzegYPwZfMN3Q=='},
#     {'text': 'Fort Lauderdale, FL', 'value': '9cr6ICcB2Yi-jr9Adb4Cdg=='},
#     {'text': 'Goodyear, AZ', 'value': 'Hbeh32U6K4f6U_mFj3qyZw=='},
#     {'text': 'Hollywood, FL', 'value': 'pzH_x2-p2YhouLd1vnrXBw=='},
#     {'text': 'Joliet, IL', 'value': 'fT027GtFDohCwGuj92aenw=='},
#     {'text': 'Kansas City, KS', 'value': 'FTXPJ-SMwIcFHsNwe3d33A=='},
#     {'text': 'Kansas City, MO', 'value': 'l5npr173wIeiUapq5iWFVQ=='},
#     {'text': "Lee's Summit, MO", 'value': '_Za1qPbfwIeHsQeg6cLSCA=='},
#     {'text': 'Los Angeles, CA', 'value': 'E9on3F3HwoD0CEYlb98v4g=='},
#     {'text': 'Minneapolis, MN', 'value': 'vbt3k5Azs1IH7novhMmfkw=='},
#     {'text': 'Montgomery, AL', 'value': '-YHUsJSBjoj_hUI1HVEbjg=='},
#     {'text': 'Nashville, TN', 'value': 'PZDrEzLsZIig2umh0Lk_fQ=='},
#     {'text': 'Oakland, CA', 'value': 'A-2qKIt9hYBnk3U11RW0cQ=='},
#     {'text': 'Orlando, FL', 'value': 'd7zN_thz54iev6U8BrLDCg=='},
#     {'text': 'Phoenix, AZ', 'value': 'y3mhUO0SK4esG0o1-MdpjA=='},
#     {'text': 'Plantation, FL', 'value': 'wxO77w8H2YgWec2NjYJ3XQ=='},
#     {'text': 'Portsmouth, NH', 'value': 'KaTUSnW_4onOTjxIabRLZQ=='},
#     {'text': 'Seattle, WA', 'value': 'VTPokywQkFSa1URpRmUlEA=='},
#     {'text': 'Tampa, FL', 'value': '4dG5s4K3wohjtJaviRNfpw=='},
#     {'text': 'Aiken, SC', 'value': 'XYHEcBpN-IhbpNlI9AoztQ=='},
#     {'text': 'Albany, NY', 'value': 'S_tPzDQK3onEKOegEmOh4Q=='},
#     {'text': 'Alexandria, VA', 'value': '8aukkz5NtoksAcHbhib11w=='},
#     {'text': 'Aloha, OR', 'value': '75GyjhoOlVRka6LLXR7ldw=='},
#     {'text': 'Alpharetta, GA', 'value': 'N_XFaJ909YhOTGUoYdUSwQ=='},
#     {'text': 'Andover, MA', 'value': '9Uyaf1kI44lWctUAXJz1KA=='},
#     {'text': 'Annapolis, MD', 'value': '1S9ncGX2t4lLJ6jT_VT4Qw=='},
#     {'text': 'Arcadia, CA', 'value': 'K8q408XbwoCLKa7S21CoTA=='},
#     {'text': 'Arcadia, IN', 'value': 'zVdeqRC8FIjHJpGkl0bNvA=='},
#     {'text': 'Arlington Heights, IL', 'value': 'N_pczju6D4jDyv3lfHBk1w=='},
#     {'text': 'Arlington, VA', 'value': 'D6ene522t4mTsPZFyG_P-A=='},
#     {'text': 'Atlanta, GA', 'value': 'jQmTaV0E9YgLYwuZL97-Zg=='},
#     {'text': 'Avondale, AZ', 'value': '80Sw0_QvK4cPT0OpGUw1RQ=='},
#     {'text': 'Baker, MT', 'value': 'U_Spt67tL1M6za2ua4Njag=='},
#     {'text': 'Bala Cynwyd, PA', 'value': '7e-ZaKK4xols4Jb3ae4UaQ=='},
#     {'text': 'Bastrop, LA', 'value': '87EhTkphLobHzlfI6eH_mQ=='},
#     {'text': 'Baton Rouge, LA', 'value': 'y3RfMmc4JIYdmleR2_EjIQ=='},
#     {'text': 'Bedminster, NJ', 'value': 'p2H32reWw4ngyCcKG_XRRw=='},
#     {'text': 'Bennington, NH', 'value': '8fc3gC4q4olzPehI39a3Qg=='}]},
#   {'type': 'Date posted',
#    'param': 'date_posted',
#    'options': [{'text': 'All'},
#     {'text': 'Past day', 'value': 'today'},
#     {'text': 'Past 3 days', 'value': '3days'},
#     {'text': 'Past week', 'value': 'week'},
#     {'text': 'Past month', 'value': 'month'}]},
#   {'type': 'Requirements',
#    'param': 'requirements',
#    'options': [{'text': 'All'},
#     {'text': 'No degree', 'value': 'no_degree'},
#     {'text': 'No experience', 'value': 'no_experience'},
#     {'text': 'Under 3 years of experience', 'value': 'years3under'},
#     {'text': '3+ years of experience', 'value': 'years3plus'}]},
#   {'type': 'Type',
#    'param': 'employment_type',
#    'options': [{'text': 'All'},
#     {'text': 'Full-time', 'value': 'FULLTIME'},
#     {'text': 'Part-time', 'value': 'PARTTIME'},
#     {'text': 'Contractor', 'value': 'CONTRACTOR'},
#     {'text': 'Internship', 'value': 'INTERN'}]},
#   {'type': 'Company type',
#    'param': 'industry.id',
#    'options': [{'text': 'All'},
#     {'text': 'Education', 'value': '/business/naics2007/61'},
#     {'text': 'Health Care', 'value': '/business/naics2007/62'},
#     {'text': 'Retail', 'value': '/business/naics2007/44'},
#     {'text': 'Staffing', 'value': '/business/naics2007/5613'},
#     {'text': 'Entertainment', 'value': '/business/naics2007/71'},
#     {'text': 'Consulting', 'value': '/business/naics2007/5416'},
#     {'text': 'Information', 'value': '/business/naics2007/51'},
#     {'text': 'Restaurant', 'value': '/business/naics2007/722'}]},
#   {'type': 'Employer',
#    'param': 'organization_mid',
#    'options': [{'text': 'All'},
#     {'text': 'Bright Horizons', 'value': '/m/03p1p5p'},
#     {'text': 'Swing Education', 'value': '/g/11g9n6y7_y'},
#     {'text': 'Broward County Public Schools', 'value': '/m/064qzh'},
#     {'text': 'Guitar Center', 'value': '/m/045zww'},
#     {'text': 'Kelly', 'value': '/m/03p2hqb'},
#     {'text': 'KIPP', 'value': '/m/079x_k'},
#     {'text': 'New Story Schools', 'value': '/g/11l2jvy3c5'},
#     {'text': 'EF English First', 'value': '/m/0bbxh2_'},
#     {'text': 'Harmony Public Schools', 'value': '/m/0fp_wfm'},
#     {'text': 'KINDERCARE', 'value': '/m/07n91t'},
#     {'text': 'The Goddard School', 'value': '/m/05sysqs'},
#     {'text': 'Crème de la Crème, Inc.', 'value': '/g/11fy1y_1hv'},
#     {'text': 'Alabama State Department of Education', 'value': '/m/07s6yc1'},
#     {'text': 'Charter Schools USA', 'value': '/m/0s8tjv0'},
#     {'text': 'Life Time', 'value': '/m/03p2k43'},
#     {'text': 'Ombudsman Educational Services', 'value': '/m/0100qkz5'},
#     {'text': 'Peoria Unified School District', 'value': '/g/1wzt2vh7'},
#     {'text': 'Region One Education Service Center', 'value': '/g/11fy2fp8rd'},
#     {'text': 'THE LEONA GROUP', 'value': '/m/0fp_yr_'},
#     {'text': 'Trinity Christian School', 'value': '/m/027w8m_'},
#     {'text': 'AB Staffing Solutions', 'value': '/g/11g9mpypd5'},
#     {'text': 'ACCEL Schools', 'value': '/g/11hbqlqx1t'},
#     {'text': 'Amtex Systems Inc.', 'value': '/g/11dxphcpp1'},
#     {'text': 'Aspire Public Schools', 'value': '/g/11g9n15df3'}]}]}

# %% [markdown]
# ## Request the output by calling REST

# %%
import os
import requests
import json
import boto3

# Make sure the data folder exists
data_folder = "data"
if not os.path.exists(data_folder):
    os.makedirs(data_folder)

# Make the GET request
response = requests.get(
    f"https://api.apify.com/v2/datasets/mj6RWZ0pjBY2aLhmq/items?token={APIFY_TOKEN}"
)

# Check if the request was successful
if response.status_code == 200:
    # Save the response content as JSON
    data = response.json()

    FILE_NAME = "data/output.json"
    # Save the JSON data to a file
    with open(FILE_NAME, "w") as file:
        json.dump(data, file)

    # Upload the JSON file to S3 bucket
    s3 = boto3.client("s3")  # Boto3 will automatically search for credentials
    bucket_name = "job-recommender-bucket-yusa"
    s3.upload_file(FILE_NAME, bucket_name, FILE_NAME)
else:
    print("Error: Failed to retrieve data")

# %% [markdown]
# ## Peak the returned JSON

# %%
len(data)
# Out:
# 4

# %%
page_1_jobs = data[1]["googleJobs"]

# %%
len(page_1_jobs)
# Out:
# 10

# %%
page_1_jobs[0].keys()
# Out:
# dict_keys(['title', 'companyName', 'location', 'via', 'description', 'jobHighlights', 'relatedLinks', 'thumbnail', 'extras', 'metadata', 'applyLink'])

# %%
job_0 = page_1_jobs[0]
job_0
# Out:
# {'title': 'Data Scientist II (Canada Remote)',
#  'companyName': 'Fullscript',
#  'location': '  Ottawa, ON, Canada   ',
#  'via': 'via Work In Tech Job Board - Communitech',
#  'description': "Embracing a new era in patient care, Fullscript is a trailblazing health technology company changing the way health is prescribed.\n\nWe know the conventional model of patient care is ripe for innovation. At Fullscript, our work is guided by our mission of creating meaningful change for the future of our healthcare systems, so that integrative medicine will one day simply be called medicine.\n\nFullscript’s care delivery platform combines customized treatment planning, wellness protocols, data insights and ongoing wellness support, with the ability to prescribe and manage the use of healthcare’s best supplements all in one place. Above all else, Fullscript is trusted by practitioners due to an unrelenting focus on quality and a patient experience that can’t be found anywhere else.\n\nWith over 5 million patients served and 70,000+ practitioners supported across North America, we’re just getting started.\n\nCome build a healthier future with us.\n\nThe Data team is a key strategic partner at... Fullscript, responsible for providing analytical support for all internal functions to drive effective planning and decision making. Reporting to a Technical Lead, the Data Scientist will perform in-depth exploration and analysis of company data in order to guide goals, improve processes, and help our leaders understand and track key metrics.\nWhat you'll do\n• Partner with key stakeholders to dive deep into the business challenges and identify insights to drive company strategies\n• Build statistical models and partner with our machine learning team to productionize impactful machine learning solutions\n• Improve data availability and data literacy across the organization\n• Collaborate with the Analytics Engineering team to improve the availability of reliable data and automation of recurring business needs\n• Partner with stakeholders to create meaningful goals and targets for both team and company-level initiatives\n• Support, facilitate, and monitor strategic objectives through the creation of data science models, segmentation, and analytical testing\n• Guide and advise business functions on the collection of data to broaden our visibility into company activities\n• Proactively contribute to our shared documentation store and self-serve Business Intelligence artifacts\n• Proactively watch for opportunities to improve code quality and scalability within our codebase\n• Define, design, and develop dashboards and artifacts for key metrics and KPIs using various data languages and Business Intelligence systems\n• Other duties may be assigned as determined by the Company from time to time\nWhat you bring to the table\n• Minimum Bachelor’s Degree in a quantitative, analytical, or similar field with 2+ years of relevant experience successfully working in a data role using relational databases\n• Experience building Statistical and Machine Learning models using a programming language like Python.\n• Experience working with Business Intelligence systems and tools (BI tooling, databases, spreadsheets)\n• Proficiency in SQL including basic transformations\n• Creative problem-solving skills with a passion for uncovering strategic opportunities\n• Proven ability to work independently in a fast-paced environment, managing competing priorities on multiple simultaneous projects\n• Demonstrated attention to detail\n• Strong written and verbal communication skills with the ability to effectively communicate complex ideas and concepts to both technical and non-technical teams\nBonus if you have:\n• Experience with Snowflake, MySQL\n• Experience with Looker\n• Experience with Python\n• Experience with HTML/CSS\n• Experience in B2B or SaaS, working in a high-growth environment\n• Interest or experience in Health Tech, Integrative Medicine, or supplements\nWhat we can offer you\n• Generous PTO and competitive pay\n• Fullscript’s RRSP match program for financial health\n• Flexible benefits package and workplace wellness program\n• Trainin ...
#  'jobHighlights': [{'items': ["Embracing a new era in patient care, Fullscript is a trailblazing health technology company changing the way health is prescribed.\n\nWe know the conventional model of patient care is ripe for innovation. At Fullscript, our work is guided by our mission of creating meaningful change for the future of our healthcare systems, so that integrative medicine will one day simply be called medicine.\n\nFullscript’s care delivery platform combines customized treatment planning, wellness protocols, data insights and ongoing wellness support, with the ability to prescribe and manage the use of healthcare’s best supplements all in one place. Above all else, Fullscript is trusted by practitioners due to an unrelenting focus on quality and a patient experience that can’t be found anywhere else.\n\nWith over 5 million patients served and 70,000+ practitioners supported across North America, we’re just getting started.\n\nCome build a healthier future with us.\n\nThe Data team is a key strategic partner at... Fullscript, responsible for providing analytical support for all internal functions to drive effective planning and decision making. Reporting to a Technical Lead, the Data Scientist will perform in-depth exploration and analysis of company data in order to guide goals, improve processes, and help our leaders understand and track key metrics.\nWhat you'll do\n• Partner with key stakeholders to dive deep into the business challenges and identify insights to drive company strategies\n• Build statistical models and partner with our machine learning team to productionize impactful machine learning solutions\n• Improve data availability and data literacy across the organization\n• Collaborate with the Analytics Engineering team to improve the availability of reliable data and automation of recurring business needs\n• Partner with stakeholders to create meaningful goals and targets for both team and company-level initiatives\n• Support, facilitate, and monitor strategic objectives through the creation of data science models, segmentation, and analytical testing\n• Guide and advise business functions on the collection of data to broaden our visibility into company activities\n• Proactively contribute to our shared documentation store and self-serve Business Intelligence artifacts\n• Proactively watch for opportunities to improve code quality and scalability within our codebase\n• Define, design, and develop dashboards and artifacts for key metrics and KPIs using various data languages and Business Intelligence systems\n• Other duties may be assigned as determined by the Company from time to time\nWhat you bring to the table\n• Minimum Bachelor’s Degree in a quantitative, analytical, or similar field with 2+ years of relevant experience successfully working in a data role using relational databases\n• Experience building Statistical and Machine Learning models using a programming language like Python.\n• Experience working with Business Intelligence systems and tools (BI tooling, databases, spreadsheets)\n• Proficiency in SQL including basic transformations\n• Creative problem-solving skills with a passion for uncovering strategic opportunities\n• Proven ability to work independently in a fast-paced environment, managing competing priorities on multiple simultaneous projects\n• Demonstrated attention to detail\n• Strong written and verbal communication skills with the ability to effectively communicate complex ideas and concepts to both technical and non-technical teams\nBonus if you have:\n• Experience with Snowflake, MySQL\n• Experience with Looker\n• Experience with Python\n• Experience with HTML/CSS\n• Experience in B2B or SaaS, working in a high-growth environment\n• Interest or experience in Health Tech, Integrative Medicine, or supplements\nWhat we can offer you\n• Generous PTO and competitive pay\n• Fullscript’s RRSP match program for financial health\n• Flexible benefits package and workplace wellness prog ...
#  'relatedLinks': [{'link': 'http://www.naturalpartners.com/',
#    'text': 'naturalpartners.com'},
#   {'link': 'https://www.google.com/search?sa=X&sca_esv=593323398&q=Fullscript&ved=0ahUKEwi80PKj0qaDAxVEEFkFHWBjA_U4ChCYkAIIxAk',
#    'text': 'See web results for Fullscript'}],
#  'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQcIJ0CgeU-2WhummXJYcY8CDh3j0mnxPkEjQdePlg&s',
#  'extras': ['Full-time'],
#  'metadata': {'scheduleType': 'Full-time'},
#  'applyLink': {'title': '.nFg2eb{font-weight:500}.Bi6Ddc{font-weight:500}Apply on Work In Tech Job Board - Communitech',
#   'link': 'https://www1.communitech.ca/companies/fullscript/jobs/31257911-data-scientist-ii-canada-remote?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}}

# %%
job_0["extras"][0]
# Out:
# 'Full-time'

# %%
job_0['applyLink']['link']
# Out:
# 'https://www1.communitech.ca/companies/fullscript/jobs/31257911-data-scientist-ii-canada-remote?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'

# %% [markdown]
# ### Note that the description and jonHighlights have the same information

# %%
print(job_0['description'])
# Out:
# Embracing a new era in patient care, Fullscript is a trailblazing health technology company changing the way health is prescribed.
#
# We know the conventional model of patient care is ripe for innovation. At Fullscript, our work is guided by our mission of creating meaningful change for the future of our healthcare systems, so that integrative medicine will one day simply be called medicine.
#
# Fullscript’s care delivery platform combines customized treatment planning, wellness protocols, data insights and ongoing wellness support, with the ability to prescribe and manage the use of healthcare’s best supplements all in one place. Above all else, Fullscript is trusted by practitioners due to an unrelenting focus on quality and a patient experience that can’t be found anywhere else.
#
# With over 5 million patients served and 70,000+ practitioners supported across North America, we’re just getting started.
#
# Come build a healthier future with us.
#
# The Data team is a key strategic partner at... Fullscript, responsible for providing analytical support for all internal functions to drive effective planning and decision making. Reporting to a Technical Lead, the Data Scientist will perform in-depth exploration and analysis of company data in order to guide goals, improve processes, and help our leaders understand and track key metrics.
# What you'll do
# • Partner with key stakeholders to dive deep into the business challenges and identify insights to drive company strategies
# • Build statistical models and partner with our machine learning team to productionize impactful machine learning solutions
# • Improve data availability and data literacy across the organization
# • Collaborate with the Analytics Engineering team to improve the availability of reliable data and automation of recurring business needs
# • Partner with stakeholders to create meaningful goals and targets for both team and company-level initiatives
# • Support, facilitate, and monitor strategic objectives through the creation of data science models, segmentation, and analytical testing
# • Guide and advise business functions on the collection of data to broaden our visibility into company activities
# • Proactively contribute to our shared documentation store and self-serve Business Intelligence artifacts
# • Proactively watch for opportunities to improve code quality and scalability within our codebase
# • Define, design, and develop dashboards and artifacts for key metrics and KPIs using various data languages and Business Intelligence systems
# • Other duties may be assigned as determined by the Company from time to time
# What you bring to the table
# • Minimum Bachelor’s Degree in a quantitative, analytical, or similar field with 2+ years of relevant experience successfully working in a data role using relational databases
# • Experience building Statistical and Machine Learning models using a programming language like Python.
# • Experience working with Business Intelligence systems and tools (BI tooling, databases, spreadsheets)
# • Proficiency in SQL including basic transformations
# • Creative problem-solving skills with a passion for uncovering strategic opportunities
# • Proven ability to work independently in a fast-paced environment, managing competing priorities on multiple simultaneous projects
# • Demonstrated attention to detail
# • Strong written and verbal communication skills with the ability to effectively communicate complex ideas and concepts to both technical and non-technical teams
# Bonus if you have:
# • Experience with Snowflake, MySQL
# • Experience with Looker
# • Experience with Python
# • Experience with HTML/CSS
# • Experience in B2B or SaaS, working in a high-growth environment
# • Interest or experience in Health Tech, Integrative Medicine, or supplements
# What we can offer you
# • Generous PTO and competitive pay
# • Fullscript’s RRSP match program for financial health
# • Flexible benefits package and workplace wellness program
# • Training budget and company-wide learning initiatives
# • Discount on Fullscript catalog of products
# • Ability to work Wherever You Work Well*
# • Our Wherever You Work Well philosophy means Fullscript teammates get to pick their own office — whether that’s in-office, at home, or a bit of both 🐶🏡
#
# Fullscript is committed to diversity in its workforce and is proud to be an equal opportunity employer. We are excited to work with talented people, period. All employment decisions are based on business needs, job requirements, and individual qualifications, without regard to race, color, religion or belief, national or ethnic origin, gender, age, disability, sexual orientation, gender identity and/or expression, marital or civil status, political affiliation, family or parental status, or any other status protected by the laws or regulations in the jurisdictions in which we operate.
#
# Accommodations are available on request for candidates taking part in all aspects of the selection process. Please send an email to accommodations@fullscript.com and let us know the nature of your request and your contact information.
#
# Our team handles a lot of sensitive information, which means we require all candidates that receive and accept employment offers to complete a background check before being hired

# %%
test_description = job_0["jobHighlights"][0]["items"][0]
print(test_description)
# Out:
# Embracing a new era in patient care, Fullscript is a trailblazing health technology company changing the way health is prescribed.
#
# We know the conventional model of patient care is ripe for innovation. At Fullscript, our work is guided by our mission of creating meaningful change for the future of our healthcare systems, so that integrative medicine will one day simply be called medicine.
#
# Fullscript’s care delivery platform combines customized treatment planning, wellness protocols, data insights and ongoing wellness support, with the ability to prescribe and manage the use of healthcare’s best supplements all in one place. Above all else, Fullscript is trusted by practitioners due to an unrelenting focus on quality and a patient experience that can’t be found anywhere else.
#
# With over 5 million patients served and 70,000+ practitioners supported across North America, we’re just getting started.
#
# Come build a healthier future with us.
#
# The Data team is a key strategic partner at... Fullscript, responsible for providing analytical support for all internal functions to drive effective planning and decision making. Reporting to a Technical Lead, the Data Scientist will perform in-depth exploration and analysis of company data in order to guide goals, improve processes, and help our leaders understand and track key metrics.
# What you'll do
# • Partner with key stakeholders to dive deep into the business challenges and identify insights to drive company strategies
# • Build statistical models and partner with our machine learning team to productionize impactful machine learning solutions
# • Improve data availability and data literacy across the organization
# • Collaborate with the Analytics Engineering team to improve the availability of reliable data and automation of recurring business needs
# • Partner with stakeholders to create meaningful goals and targets for both team and company-level initiatives
# • Support, facilitate, and monitor strategic objectives through the creation of data science models, segmentation, and analytical testing
# • Guide and advise business functions on the collection of data to broaden our visibility into company activities
# • Proactively contribute to our shared documentation store and self-serve Business Intelligence artifacts
# • Proactively watch for opportunities to improve code quality and scalability within our codebase
# • Define, design, and develop dashboards and artifacts for key metrics and KPIs using various data languages and Business Intelligence systems
# • Other duties may be assigned as determined by the Company from time to time
# What you bring to the table
# • Minimum Bachelor’s Degree in a quantitative, analytical, or similar field with 2+ years of relevant experience successfully working in a data role using relational databases
# • Experience building Statistical and Machine Learning models using a programming language like Python.
# • Experience working with Business Intelligence systems and tools (BI tooling, databases, spreadsheets)
# • Proficiency in SQL including basic transformations
# • Creative problem-solving skills with a passion for uncovering strategic opportunities
# • Proven ability to work independently in a fast-paced environment, managing competing priorities on multiple simultaneous projects
# • Demonstrated attention to detail
# • Strong written and verbal communication skills with the ability to effectively communicate complex ideas and concepts to both technical and non-technical teams
# Bonus if you have:
# • Experience with Snowflake, MySQL
# • Experience with Looker
# • Experience with Python
# • Experience with HTML/CSS
# • Experience in B2B or SaaS, working in a high-growth environment
# • Interest or experience in Health Tech, Integrative Medicine, or supplements
# What we can offer you
# • Generous PTO and competitive pay
# • Fullscript’s RRSP match program for financial health
# • Flexible benefits package and workplace wellness program
# • Training budget and company-wide learning initiatives
# • Discount on Fullscript catalog of products
# • Ability to work Wherever You Work Well*
# • Our Wherever You Work Well philosophy means Fullscript teammates get to pick their own office — whether that’s in-office, at home, or a bit of both 🐶🏡
#
# Fullscript is committed to diversity in its workforce and is proud to be an equal opportunity employer. We are excited to work with talented people, period. All employment decisions are based on business needs, job requirements, and individual qualifications, without regard to race, color, religion or belief, national or ethnic origin, gender, age, disability, sexual orientation, gender identity and/or expression, marital or civil status, political affiliation, family or parental status, or any other status protected by the laws or regulations in the jurisdictions in which we operate.
#
# Accommodations are available on request for candidates taking part in all aspects of the selection process. Please send an email to accommodations@fullscript.com and let us know the nature of your request and your contact information.
#
# Our team handles a lot of sensitive information, which means we require all candidates that receive and accept employment offers to complete a background check before being hired

# %% [markdown]
# ## Explorer other saving options

# %%
import boto3

# Create a DynamoDB client
dynamodb = boto3.client('dynamodb')

# Define the table name
table_name = 'your_table_name'

# Define the dictionary to be saved
data = {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}

# Save the dictionary to DynamoDB
response = dynamodb.put_item(
    TableName=table_name,
    Item=data
)

# Print the response
print(response)

# %% [markdown]
# # Langchain parsing

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.llms import OpenAI
from langchain.chains import LLMChain
from langchain.chat_models import ChatOpenAI
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    AIMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain.schema import AIMessage, HumanMessage, SystemMessage
from langchain.prompts import PromptTemplate

llm = OpenAI(temperature=0.9, max_tokens=3000)

# %%
system_message_prompt = SystemMessagePromptTemplate(
    prompt=PromptTemplate(
        template="For the following json objet, please help me parse the following infotmation and \
            save into a json object with the following keys \
                (job_title, company_name, location, source, \
                    full_text_description, job_type(full_time/ part_time/ contract/ ...), link)",
        input_variables=[],
    )
)

human_message_prompt = HumanMessagePromptTemplate(
    prompt=PromptTemplate(
        template="The following is the parsed job description json object {json}?",
        input_variables=["json"],
    )
)
chat_prompt_template = ChatPromptTemplate.from_messages(
    [system_message_prompt, human_message_prompt]
)
chat = ChatOpenAI(temperature=0.9)
chain = LLMChain(llm=chat, prompt=chat_prompt_template)
parsed_jd = chain.run(json=job_0)

print(parsed_jd)
# Out:
# The parsed job description JSON object can be transformed into the following format:
#
# {
#    "job_title": "Data Scientist II (Canada Remote)",
#    "company_name": "Fullscript",
#    "location": "Ottawa, ON, Canada",
#    "source": "via Work In Tech Job Board - Communitech",
#    "full_text_description": "Embracing a new era in patient care, Fullscript is a trailblazing health technology company changing the way health is prescribed.\n\nWe know the conventional model of patient care is ripe for innovation. At Fullscript, our work is guided by our mission of creating meaningful change for the future of our healthcare systems, so that integrative medicine will one day simply be called medicine.\n\nFullscript’s care delivery platform combines customized treatment planning, wellness protocols, data insights and ongoing wellness support, with the ability to prescribe and manage the use of healthcare’s best supplements all in one place. Above all else, Fullscript is trusted by practitioners due to an unrelenting focus on quality and a patient experience that can’t be found anywhere else.\n\nWith over 5 million patients served and 70,000+ practitioners supported across North America, we’re just getting started.\n\nCome build a healthier future with us.\n\nThe Data team is a key strategic partner at... Fullscript, responsible for providing analytical support for all internal functions to drive effective planning and decision making. Reporting to a Technical Lead, the Data Scientist will perform in-depth exploration and analysis of company data in order to guide goals, improve processes, and help our leaders understand and track key metrics.\nWhat you'll do\n• Partner with key stakeholders to dive deep into the business challenges and identify insights to drive company strategies\n• Build statistical models and partner with our machine learning team to productionize impactful machine learning solutions\n• Improve data availability and data literacy across the organization\n• Collaborate with the Analytics Engineering team to improve the availability of reliable data and automation of recurring business needs\n• Partner with stakeholders to create meaningful goals and targets for both team and company-level initiatives\n• Support, facilitate, and monitor strategic objectives through the creation of data science models, segmentation, and analytical testing\n• Guide and advise business functions on the collection of data to broaden our visibility into company activities\n• Proactively contribute to our shared documentation store and self-serve Business Intelligence artifacts\n• Proactively watch for opportunities to improve code quality and scalability within our codebase\n• Define, design, and develop dashboards and artifacts for key metrics and KPIs using various data languages and Business Intelligence systems\n• Other duties may be assigned as determined by the Company from time to time\nWhat you bring to the table\n• Minimum Bachelor’s Degree in a quantitative, analytical, or similar field with 2+ years of relevant experience successfully working in a data role using relational databases\n• Experience building Statistical and Machine Learning models using a programming language like Python.\n• Experience working with Business Intelligence systems and tools (BI tooling, databases, spreadsheets)\n• Proficiency in SQL including basic transformations\n• Creative problem-solving skills with a passion for uncovering strategic opportunities\n• Proven ability to work independently in a fast-paced environment, managing competing priorities on multiple simultaneous projects\n• Demonstrated attention to detail\n• Strong written and verbal communication skills with the ability to effectively communicate complex ideas and concepts to both technical and non-technical teams\nBonus if you have:\n• Experience with Snowflake, MySQL\n• Experience with Looker\n• Experience with Python\n• Experience with HTML/CSS\n• Experience in B2B or SaaS, working in a high-growth environment\n• Interest or experience in Health Tech, Integrative Medicine, or supplements\nWhat we can offer you\n• Generous PTO and competitive pay\n• Fullscript’s RRSP match program for financial health\n• Flexible benefits package and workplace wellness progra ...
#    "job_type": "Full-time",
#    "link": "https://www1.communitech.ca/companies/fullscript/jobs/31257911-data-scientist-ii-canada-remote?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
# }
